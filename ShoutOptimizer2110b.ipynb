# %% [markdown]
# # Shout Optimizer data processing
#
# The aim of this tool is to create a price estimator for new products on an online auction site.
# * Data is downloaded from Huuto.net API
# * Items are clustered together using machine learning
# * Same clusters have only same item
# * An average price for cluster is calculated

# %%
import pandas as pd
import numpy as np

import string

import re

import csv

from gensim.models import phrases, Word2Vec

from sklearn.cluster import KMeans
from sklearn import cluster
from sklearn import metrics

from sklearn.cluster import AgglomerativeClustering

from ast import literal_eval


from gensim.test.utils import datapath
from gensim.models.word2vec import Text8Corpus
from gensim.models.phrases import Phrases, Phraser

import gensim
import gensim.downloader as api

# %%
# Assess sample size for test purposes
sample = 1500

# Import data that has been downloaded from huuto.net API
df = pd.read_csv('ps2_data.csv')

# Print columns to inspect data
print(df.columns)

# Apply eval function to links because they are a list, not String
df['links']=df['links'].apply(literal_eval)

# Subset data with sample variable
#df = df[:sample].copy()
# Out:
# Index(['Unnamed: 0', 'index', 'links', 'id', 'title', 'category', 'seller',
#        'sellerId', 'currentPrice', 'buyNowPrice', 'saleMethod', 'listTime',
#        'postalCode', 'location', 'closingTime', 'bidderCount', 'offerCount',
#        'hasReservePrice', 'hasReservePriceExceeded', 'upgrades', 'images'],
#       dtype='object')
# {'self': 'https://api.huuto.net/1.1/items/520206177',
#  'category': 'https://api.huuto.net/1.1/categories/459',
#  'alternative': 'https://www.huuto.net/kohteet/the-scorpion-king---rise-of-the-akkadian-ps2/520206177',
#  'images': 'https://api.huuto.net/1.1/items/520206177/images'}

# %% [markdown]
# ### Preprocessing

# %%
# Take only wanted columns from dataset
tdf = df[['title','links','currentPrice']].copy()

# Lower case all titles
tdf['title'] = tdf['title'].str.lower()
tdf['title'][100]
# Out:
# 'transformers - the game ps2'

# %% [markdown]
# ##### Remove punctuation:

# %%
tdf['title'] = tdf['title'].str.replace('[{}]'.format(string.punctuation),' ')
tdf['title'][100]
# Out:
# 'transformers game'

# %% [markdown]
# ##### Remove stopwords and extra whitespace:

# %%
with open('stop-word-list_huuto.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        stopwords = row
stopwords = list(map(str.strip, stopwords))
#remove empties

# %%
def RemoveSpace(word):
    regex = re.compile(r'[\n\r\t\xa0]')
    word = regex.sub(" ", word)
    _RE_COMBINE_WHITESPACE = re.compile(r"(?a:\s+)")
    _RE_STRIP_WHITESPACE = re.compile(r"(?a:^\s+|\s+$)")
    
    word = _RE_COMBINE_WHITESPACE.sub(" ", word)
    word = _RE_STRIP_WHITESPACE.sub("", word) 
    return word

# %%
tdf['title'] = tdf['title'].str.replace(f'\\b({"|".join(stopwords)})\\b','')        
tdf['title'] = tdf['title'].apply(lambda x: (RemoveSpace(x)))
titles2 = tdf
titles2['title'][1440:1450]
# Out:
# 1440                                              jak x
# 1441                         crash bandicoot nitro kart
# 1442                                       sonic heroes
# 1443    tom clancy s splinter cell pandora tomorrow 467
# 1444                                        deus ex 460
# 1445                                           singstar
# 1446
# 1447                 star wars episode iii revenge sith
# 1448                                       sonic heroes
# 1449                           alone dark new nightmare
# Name: title, dtype: object

# %%
# Remove empty titles
titles2 = titles2[titles2['title'] != ''].copy()
titles2= titles2.reset_index(drop=True)
titles2[1440:1450]
# Out:
#                                                 title  \
# 1440                                            jak x
# 1441                       crash bandicoot nitro kart
# 1442                                     sonic heroes
# 1443  tom clancy s splinter cell pandora tomorrow 467
# 1444                                      deus ex 460
# 1445                                         singstar
# 1446               star wars episode iii revenge sith
# 1447                                     sonic heroes
# 1448                         alone dark new nightmare
# 1449                            nhl 2k8 playstation 2
#
#                                                   links  currentPrice
# 1440  {'self': 'https://api.huuto.net/1.1/items/5201...         10.00
# 1441  {'self': 'https://api.huuto.net/1.1/items/5206...         20.00
# 1442  {'self': 'https://api.huuto.net/1.1/items/5201...          9.00
# 1443  {'self': 'https://api.huuto.net/1.1/items/5243...          4.00
# 1444  {'self': 'https://api.huuto.net/1.1/items/5243...          8.00
# 1445  {'self': 'https://api.huuto.net/1.1/items/5246...          6.00
# 1446  {'self': 'https://api.huuto.net/1.1/items/5245...          4.15
# 1447  {'self': 'https://api.huuto.net/1.1/items/5229...          5.00
# 1448  {'self': 'https://api.huuto.net/1.1/items/5222...         16.00
# 1449  {'self': 'https://api.huuto.net/1.1/items/5238...          5.00

# %% [markdown]
# #### Create lists of words

# %%
titles2['title'] = titles2['title'].str.split()
dataset = titles2
dataset[:10]
# Out:
#                              title  \
# 0   [racing, simulation, 3, 10244]
# 1        [sopranos, road, respect]
# 2               [red, faction, ii]
# 3                [reservoir, dogs]
# 4      [lego, batman, video, game]
# 5             [ratchet, gladiator]
# 6   [star, wars, force, unleashed]
# 7           [star, trek, conquest]
# 8  [mercenaries, 2, world, flames]
# 9  [men, black, ii, alien, escape]
#
#                                                links  currentPrice
# 0  {'self': 'https://api.huuto.net/1.1/items/5199...           4.5
# 1  {'self': 'https://api.huuto.net/1.1/items/5199...          12.0
# 2  {'self': 'https://api.huuto.net/1.1/items/5199...           8.0
# 3  {'self': 'https://api.huuto.net/1.1/items/5200...          12.0
# 4  {'self': 'https://api.huuto.net/1.1/items/5198...          10.0
# 5  {'self': 'https://api.huuto.net/1.1/items/5201...          10.0
# 6  {'self': 'https://api.huuto.net/1.1/items/5201...          11.0
# 7  {'self': 'https://api.huuto.net/1.1/items/5201...          10.0
# 8  {'self': 'https://api.huuto.net/1.1/items/5201...           8.0
# 9  {'self': 'https://api.huuto.net/1.1/items/5201...           9.0

# %% [markdown]
# ## Bigrams with gensim Phrases

# %%
sentences = dataset.copy()

sentences
# Out:
#                                   title  \
# 0        [racing, simulation, 3, 10244]
# 1             [sopranos, road, respect]
# 2                    [red, faction, ii]
# 3                     [reservoir, dogs]
# 4           [lego, batman, video, game]
# ...                                 ...
# 6040              [sims, 2, autiosaari]
# 6041            [v, rally, 3, käytetty]
# 6042  [forgotten, realms, demon, stone]
# 6043        [nhl, 2001, playstation, 2]
# 6044                        [nhl, 2001]
#
#                                                   links  currentPrice
# 0     {'self': 'https://api.huuto.net/1.1/items/5199...           4.5
# 1     {'self': 'https://api.huuto.net/1.1/items/5199...          12.0
# 2     {'self': 'https://api.huuto.net/1.1/items/5199...           8.0
# 3     {'self': 'https://api.huuto.net/1.1/items/5200...          12.0
# 4     {'self': 'https://api.huuto.net/1.1/items/5198...          10.0
# ...                                                 ...           ...
# 6040  {'self': 'https://api.huuto.net/1.1/items/5261...           1.0
# 6041  {'self': 'https://api.huuto.net/1.1/items/5260...           8.5
# 6042  {'self': 'https://api.huuto.net/1.1/items/5255...           3.8
# 6043  {'self': 'https://api.huuto.net/1.1/items/5238...           3.0
# 6044  {'self': 'https://api.huuto.net/1.1/items/5258...          10.0
#
# [6045 rows x 3 columns]

# %%
# Create bigrams with gensim phrases.
# Bigrams are identified naturally from the data, for example 'star', 'wars' -> 'star_wars'
# This will help distinguish for example Star Wars and Star Trek from each other.
# It also works as dimensionality reduction.

phrases = Phrases(sentences['title'], min_count=1, threshold=1)

bigram = Phraser(phrases)

# %%
bigrams = phrases.Phrases(sentences['title'])
bigrams[sentences['title']]

# %%
# Initialize the bigrams column in sentences DataFrame

sentences['bigrams']=''

# Create a list of bigrams for each row

for index, row in sentences.iterrows():
    i  = bigram[row['title']]
    sentences.at[index,'bigrams']=i
# Out:
# ['lego_batman', 'video_game']

# %%
# Make a Word2Vec vectorization with bigrams
# Note: this is not used, but it is left here for future development purposes

m = Word2Vec(sentences['bigrams'], size =50, min_count=1, sg=1, iter=20)

# Test to see results of the model

m.wv.most_similar('force_unleashed')

# %%
# Turn Word2Vec vectorization into a more usable form
# Note: this is not used, but it is left here for future development purposes

def vectorizer(sent,m):
    vec =[]
    numw =0
    for w in sent:
        try:
            if numw == 0:
                vec = m[w]
            else: vec = np.add(vec, m[w])
            numw +=1
        except:
            pass
        
    return np.asarray(vec) / numw
# Out:
# C:\Users\tipe_\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\tipe_\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
# Run the vectorizer function
# Note: this is not used, but it is left here for future development purposes

l=[]
for i in sentences['bigrams']:
    l.append(vectorizer(i,m))
X = np.array(l)

# %%
# Check X
# Note: this is not used, but it is left here for future development purposes

X
# Out:
# array([[-7.7660196e-05,  1.8645324e-03, -2.9357316e-03, ...,
#          3.6388212e-03, -2.2470416e-03,  4.2536426e-03],
#        [-6.4247204e-03,  6.3266405e-03,  5.3309620e-04, ...,
#         -3.7191394e-03, -3.3003383e-04, -2.2671768e-03],
#        [-3.8311707e-03,  1.5928482e-03, -2.9937066e-03, ...,
#          1.9909623e-03, -3.2473728e-03,  1.8449014e-03],
#        ...,
#        [-3.4147839e-04, -1.3880475e-03, -6.1621917e-03, ...,
#         -1.0889105e-04, -1.1411640e-03,  9.5788436e-03],
#        [-7.1901525e-04, -1.7206230e-03, -4.3801884e-03, ...,
#          1.1538871e-03,  4.3616248e-03, -7.0206830e-03],
#        [-7.5207609e-03, -2.0042148e-03, -1.1678798e-03, ...,
#          6.0614287e-03,  6.2229461e-03, -3.8640955e-03]], dtype=float32)

# %%
# Get corpus, or vocabulary of different words and bigrams in the data

# bag of words

corpusW = []
for row in sentences['bigrams']:
    for word in row:
        if word not in corpusW:
            corpusW.append(word)

bagofwords= set(corpusW)
corpusW
# Out:
# [['ps_2', 283],
#  ['pal', 228],
#  ['2', 194],
#  ['playstation_2', 173],
#  ['need_speed', 105],
#  ['medal_honor', 105],
#  ['3', 92],
#  ['platinum', 65],
#  ['star_wars', 60],
#  ['grand_theft', 59],
#  ['final_fantasy', 59],
#  ['crash_bandicoot', 58],
#  ['tom_clancy', 56],
#  ['rising_sun', 50],
#  ['harry_potter', 50],
#  ['metal_gear', 50],
#  ['racing', 50],
#  ['4', 49],
#  ['pro_evolution', 48],
#  ['singstar_legendat', 42],
#  ['b_pal', 40],
#  ['gran_turismo', 39],
#  ['lord_rings', 39],
#  ['k', 39],
#  ['ratchet_clank', 38],
#  ['city', 37],
#  ['agent_hugo', 37],
#  ['s_splinter', 36],
#  ['ii', 36],
#  ['guitar_hero', 35],
#  ['james_bond', 34],
#  ['fight_night', 33],
#  ['lego_star', 33],
#  ['–', 32],
#  ['hits', 31],
#  ['rollercoaster_world', 31],
#  ['eyetoy_play', 31],
#  ['b', 31],
#  ['prostreet', 31],
#  ['solid_2', 30],
#  ['bakugan_battle', 29],
#  ['max_payne', 29],
#  ['sims_2', 29],
#  ['eye_toy', 28],
#  ['singstar_abba', 28],
#  ['revenge_sith', 28],
#  ['prince_persia', 27],
#  ['sons_liberty', 27],
#  ['brawlers', 27],
#  ['promo', 26],
#  ['lego_indiana', 26],
#  ['frontline', 26],
#  ['carbon', 26],
#  ['singstar_suomirock', 25],
#  ['xii', 25],
#  ['ratchet_gladiator', 25],
#  ['s', 25],
#  ['dragon_ball', 25],
#  ['singstar_pop', 25],
#  ['agent', 25],
#  ['spider_man', 25],
#  ['colin_mcrae', 24],
#  ['getaway', 24],
#  ['singstar_r', 24],
#  ['smackdown_vs', 24],
#  ['x', 24],
#  ['pal_sinetöity', 24],
#  ['episode_iii', 24],
#  ['lego_batman', 24],
#  ['2005', 23],
#  ['2002', 23],
#  ['goldeneye_rogue', 23],
#  ['pga_tour', 23],
#  ['tiger_woods', 23],
#  ['karvinen_2', 23],
#  ['z_budokai', 23],
#  ['play_station', 23],
#  ['2003', 22],
#  ['ps_ii', 22],
#  ['rock_band', 22],
#  ['jak_3', 22],
#  ['video_game', 22],
#  ['tomb_raider', 22],
#  ['special_edition', 22],
#  ['trilogy', 21],
#  ['kingdom_hearts', 21],
#  ['cell', 21],
#  ['resident_evil', 21],
#  ['game', 21],
#  ['true_crime', 21],
#  ['2004', 21],
#  ['disney_pixar', 20],
#  ['devil_may', 20],
#  ['splinter_cell', 20],
#  ['wars_ii', 19],
#  ['european_assault', 19],
#  ['tony_hawk', 19],
#  ['fire', 19],
#  ['renegade', 19],
#  ['rock', 19],
#  ['auto_vice', 19],
#  ['code', 19],
#  ['pirates_caribbean', 18],
#  ['wrath_cortex', 18],
#  ['da_vinci', 18],
#  ['sonic_riders', 18],
#  ['2007', 18],
#  ['x_2', 18],
#  ['disney_sing', 18],
#  ['undercover', 18],
#  ['dynasty_warriors', 18],
#  ['god_war', 18],
#  ['pikari', 18],
#  ['navy_seals', 18],
#  ['2_pelilevy', 18],
#  ['ja_liekehtivä', 18],
#  ['muoveissa', 18],
#  ['black', 18],
#  ['fifa_street', 17],
#  ['championship', 17],
#  ['battlefield_2', 17],
#  ['world_flames', 17],
#  ['mercenaries_2', 17],
#  ['tour', 17],
#  ['auto_iii', 17],
#  ['force', 17],
#  ['aliens', 17],
#  ['singstar', 17],
#  ['edition', 17],
#  ['star_trek', 17],
#  ['nitro_kart', 17],
#  ['ninja', 17],
#  ['chronicles_narnia', 17],
#  ['nro', 17],
#  ['gun', 17],
#  ['call_duty', 16],
#  ['under_siege', 16],
#  ['worms_forts', 16],
#  ['collection', 16],
#  ['red_faction', 16],
#  ['30', 16],
#  ['sonic_heroes', 16],
#  ['extreme', 16],
#  ['tennis', 16],
#  ['08', 16],
#  ['midnight_club', 16],
#  ['jak_x', 16],
#  ['modern_combat', 16],
#  ['cry_3', 16],
#  ['round_2', 15],
#  ['disney_s', 15],
#  ['quest', 15],
#  ['solid_3', 15],
#  ['challenge', 15],
#  ['shadow_hedgehog', 15],
#  ['pelit', 15],
#  ['high_school', 15],
#  ['cruise', 15],
#  ['storm', 15],
#  ['it', 15],
#  ['round_3', 15],
#  ['nhl_2004', 15],
#  ['24_game', 14],
#  ['rally_championship', 14],
#  ['jones_adventures', 14],
#  ['underground', 14],
#  ['rayman_raving', 14],
#  ['warrior', 14],
#  ['sum_all', 14],
#  ['socom_u', 14],
#  ['pro', 14],
#  ['fantastic_four', 14],
#  ['rabbids', 14],
#  ['hugo_cannon', 14],
#  ['up', 14],
#  ['sims', 14],
#  ['naruto_ultimate', 14],
#  ['fifa_07', 14],
#  ['fears', 14],
#  ['party', 14],
#  ['jak_and', 14],
#  ['nba_live', 14],
#  ['andreas', 14],
#  ['s_navy', 14],
#  ['sims_ryntää', 14],
#  ['bulletproof', 14],
#  ['dancing_stage', 14],
#  ['most_wanted', 13],
#  ['burnout_dominator', 13],
#  ['007_from', 13],
#  ['s_ghost', 13],
#  ['godfather', 13],
#  ['world_tour', 13],
#  ['wars_video', 13],
#  ['state_emergency', 13],
#  ['and', 13],
#  ['two_towers', 13],
#  ['50_cent', 13],
#  ['end', 13],
#  ['raitille', 13],
#  ['jak_2', 13],
#  ['boogie', 13],
#  ['ja', 13],
#  ['viewtiful_joe', 13],
#  ['3_spec', 13],
#  ['russia_with', 13],
#  ['new_york', 13],
#  ['sands_time', 13],
#  ['love', 13],
#  ['legend', 12],
#  ['monsters_vs', 12],
#  ['simpsons', 12],
#  ['enter_matrix', 12],
#  ['jones', 12],
#  ['rise_silver', 12],
#  ['city_stories', 12],
#  ['collection_plus', 12],
#  ['full_spectrum', 12],
#  ['t_o', 12],
#  ['ssx_3', 12],
#  ['fifa_08', 12],
#  ['surfer', 12],
#  ['auto_san', 12],
#  ['täysversio', 12],
#  ['wrc_ii', 12],
#  ['singstar_suomipop', 12],
#  ['iii', 12],
#  ['sonic_mega', 12],
#  ['action_man', 12],
#  ['autot', 12],
#  ['seals', 12],
#  ['hyvä', 12],
#  ['zone_enders', 12],
#  ['conquest', 12],
#  ['brothers_arms', 12],
#  ['and_prisoner', 11],
#  ['007_everything', 11],
#  ['crash_titans', 11],
#  ['lara_croft', 11],
#  ['m_alpha', 11],
#  ['prince_caspian', 11],
#  ['crazy_frog', 11],
#  ['fifa_06', 11],
#  ['azkaban', 11],
#  ['teens_machines', 11],
#  ['rally_3', 11],
#  ['hitman_2', 11],
#  ['soccer', 11],
#  ['simpsonit', 11],
#  ['power_rangers', 11],
#  ['promo_pelin', 11],
#  ['1', 11],
#  ['mortal_kombat', 11],
#  ['fifa_football', 11],
#  ['aragorn_s', 11],
#  ['road_hill', 11],
#  ['8', 11],
#  ['burnout_revenge', 11],
#  ['alone_dark', 11],
#  ['vanguard', 10],
#  ['autiosaari', 10],
#  ['quiz', 10],
#  ['conflict_global', 10],
#  ['jak_daxter', 10],
#  ['3_dub', 10],
#  ['2006', 10],
#  ['tom_clancys', 10],
#  ['rally_04', 10],
#  ['socom_3', 10],
#  ['toca_race', 10],
#  ['vs_raw', 10],
#  ['crash_nitro', 10],
#  ['worms_3d', 10],
#  ['pop_hits', 10],
#  ['mind_over', 10],
#  ['conflict_desert', 10],
#  ['international_cricket', 10],
#  ['mutant', 10],
#  ['donald_duck', 10],
#  ['daxter_precursor', 10],
#  ['getaway_black', 10],
#  ['summoner', 10],
#  ['sports', 10],
#  ['silent_assassin', 10],
#  ['demo', 10],
#  ['nhl_07', 10],
#  ['sega_superstars', 10],
#  ['pelejä', 10],
#  ['u_s', 10],
#  ['x_men', 10],
#  ['formula_one', 10],
#  ['tag_team', 10],
#  ['world_rally', 10],
#  ['world_s', 10],
#  ['flushed_away', 10],
#  ['ii_dogfight', 10],
#  ['ssx_tour', 10],
#  ['5', 10],
#  ['streets_la', 10],
#  ['moto_gp', 10],
#  ['pacific_warriors', 10],
#  ['snake_eater', 10],
#  ['panda', 9],
#  ['chronicles', 9],
#  ['silent_hill', 9],
#  ['ball_z', 9],
#  ['spongebob_squarepants', 9],
#  ['totally_spies', 9],
#  ['anniversary', 9],
#  ['games', 9],
#  ['ntsc', 9],
#  ['soccer_2008', 9],
#  ['super_dragon', 9],
#  ['teenage_mutant', 9],
#  ['samurai_warriors', 9],
#  ['disney_princess', 9],
#  ['wrc_3', 9],
#  ['world', 9],
#  ['ninja_turtles', 9],
#  ['bratz_movie', 9],
#  ['ea_sports', 9],
#  ['uefa_champions', 9],
#  ['soccer_6', 9],
#  ['07', 9],
#  ['alias', 9],
#  ['golden_compass', 9],
#  ['legend_dragon', 9],
#  ['singstar_rocks', 9],
#  ['stolen', 9],
#  ['kung_fu', 9],
#  ['hugo_bukkazoom', 9],
#  ['2008', 9],
#  ['dvd', 9],
#  ['totally_party', 9],
#  ['wrc_world', 9],
#  ['shark_tale', 9],
#  ['agent_under', 9],
#  ['juiced_2', 9],
#  ['stuntman_ignition', 9],
#  ['nothing', 9],
#  ['speed_machines', 9],
#  ['aerosmith', 9],
#  ['sonic_gems', 9],
#  ['transformers_game', 9],
#  ['eyetoy', 8],
#  ['racer', 8],
#  ['turtles', 8],
#  ['cell_chaos', 8],
#  ['reservoir_dogs', 8],
#  ['racer_2', 8],
#  ['third_age', 8],
#  ['rally', 8],
#  ['theory', 8],
#  ['tmnt_teenage', 8],
#  ['monday', 8],
#  ['guilty_gear', 8],
#  ['rescue', 8],
#  ['suomiversio', 8],
#  ['tournament', 8],
#  ['ihmeperhe', 8],
#  ['kpl', 8],
#  ['harvinainen', 8],
#  ['hoodlum_havoc', 8],
#  ['king_kong', 8],
#  ['ben_10', 8],
#  ['pk', 8],
#  ['hot_import', 8],
#  ['monsterit_oy', 8],
#  ['and_magic', 8],
#  ['nhl_08', 8],
#  ['cabela_s', 8],
#  ['legend_jack', 8],
#  ['hannah_montana', 8],
#  ['franklin_syntymäpäiväyllätys', 8],
#  ['musical_sing', 8],
#  ['finest_hour', 8],
#  ['league_2006', 8],
#  ['säikkysaari', 8],
#  ['legacy', 8],
#  ['club_football', 8],
#  ['auto_liberty', 8],
#  ['626', 8],
#  ['escape', 8],
#  ['mutant_ninja', 8],
#  ['kart', 8],
#  ['warrior_within', 8],
#  ['buzz_sporttivisa', 8],
#  ['singstar_party', 8],
#  ['golf', 8],
#  ['ghost_recon', 8],
#  ['tarzan_freeride', 8],
#  ['dark_chronicle', 8],
#  ['avaamaton', 8],
#  ['buzz', 8],
#  ['nights', 8],
#  ['3_pal', 8],
#  ['virtua_fighter', 8],
#  ['and_goblet', 8],
#  ['rayman_3', 8],
#  ['over_pacific', 7],
#  ['wall_e', 7],
#  ['operation_surma', 7],
#  ['nhl_2005', 7],
#  ['jak_ii', 7],
#  ['force_unleashed', 7],
#  ['captain_scarlet', 7],
#  ['soccer_3', 7],
#  ['lma_manager', 7],
#  ['singstar_legends', 7],
#  ['jumanji', 7],
#  ['batman_begins', 7],
#  ['gp', 7],
#  ['wwe_smackdown', 7],
#  ['prisoner_war', 7],
#  ['band_hero', 7],
#  ['shrek', 7],
#  ['outlaw_tennis', 7],
#  ['wwii_battle', 7],
#  ['second_sight', 7],
#  ['dr_dolittle', 7],
#  ['premier_manager', 7],
#  ['asterix_obelix', 7],
#  ['minority_report', 7],
#  ['dance_party', 7],
#  ['urbz_sims', 7],
#  ['point_impact', 7],
#  ['tenkaichi', 7],
#  ['new_nightmare', 7],
#  ['sniper_2', 7],
#  ['trigger_man', 7],
#  ['fate', 7],
#  ['raw', 7],
#  ['assault', 7],
#  ['burnout_3', 7],
#  ['jungle_book', 7],
#  ['song_pack', 7],
#  ['starfighter', 7],
#  ['double_agent', 7],
#  ['play_sports', 7],
#  ['yli_aidan', 7],
#  ['king_fighters', 7],
#  ['18', 7],
#  ['meet_robinsons', 7],
#  ['batman_rise', 7],
#  ['killzone', 7],
#  ['s_pro', 7],
#  ['singstar_80s', 7],
#  ['fifa_10', 7],
#  ['brian_lara', 7],
#  ['revolution', 7],
#  ['spotlight_world', 7],
#  ['peter_pan', 7],
#  ['prätkähiiret', 7],
#  ['pk_t', 7],
#  ['angels', 7],
#  ['sin_tzu', 7],
#  ['rayman_m', 7],
#  ['burnout_2', 7],
#  ['groove_party', 7],
#  ['mission_impossible', 7],
#  ['school_musical', 7],
#  ['raw_2006', 7],
#  ['football', 7],
#  ['09', 7],
#  ['terminator_dawn', 7],
#  ['arenas', 6],
#  ['iii_legends', 6],
#  ['primal', 6],
#  ['smash_court', 6],
#  ['narnia_lion', 6],
#  ['fightbox', 6],
#  ['peter_jackson', 6],
#  ['ice_age', 6],
#  ['tokobot_plus', 6],
#  ['land', 6],
#  ['top_spin', 6],
#  ['flatout_2', 6],
#  ['50', 6],
#  ['def_jam', 6],
#  ['toybots', 6],
#  ['syphon_filter', 6],
#  ['motorsiege_warriors', 6],
#  ['hain_tarina', 6],
#  ['africa', 6],
#  ['operative_no', 6],
#  ['xtreme', 6],
#  ['tennis_pro', 6],
#  ['stuntman', 6],
#  ['hockey', 6],
#  ['nhl_06', 6],
#  ['okami', 6],
#  ['wipeout_fusion', 6],
#  ['let_s', 6],
#  ['huippu', 6],
#  ['s_project', 6],
#  ['simpsons_skateboarding', 6],
#  ['turtles_smash', 6],
#  ['paavo_pesusieni', 6],
#  ['groove', 6],
#  ['kilta', 6],
#  ['mx_world', 6],
#  ['witch_and', 6],
#  ['twenty_2', 6],
#  ['stitch_experiment', 6],
#  ['incredibles_rise', 6],
#  ['x_squad', 6],
#  ['team', 6],
#  ['downtown_run', 6],
#  ['neo', 6],
#  ['legend_never', 6],
#  ['dragonball_z', 6],
#  ['takedown', 6],
#  ['chaos_theory', 6],
#  ['playstation', 6],
#  ['katamari', 6],
#  ['driver_2', 6],
#  ['play_3', 6],
#  ['super_legends', 6],
#  ['everything_nothing', 6],
#  ['shadow_hearts', 6],
#  ['2_fall', 6],
#  ['jumper_griffin', 6],
#  ['grand_prix', 6],
#  ['nicktoons_attack', 6],
#  ['mysteries_karakuri', 6],
#  ['sparrow', 6],
#  ['monster_house', 6],
#  ['chicken_little', 6],
#  ['charlie_s', 6],
#  ['ghostly_trio', 6],
#  ['ja_feeniksin', 6],
#  ['commandos_strike', 6],
#  ['world_race', 6],
#  ['storm_2', 6],
#  ['kadonnut_maailma', 6],
#  ['forever', 6],
#  ['snowboarding', 6],
#  ['rtx_red', 6],
#  ['disney', 6],
#  ['3_senior', 6],
#  ['code_veronica', 6],
#  ['singstar_anthems', 6],
#  ['rugby', 6],
#  ['primetime', 6],
#  ['bionicle_heroes', 6],
#  ['king', 6],
#  ['singstar_rock', 6],
#  ['videogame', 6],
#  ['free_running', 6],
#  ['run', 6],
#  ['madden_nfl', 6],
#  ['it_pop', 6],
#  ['recon_advanced', 6],
#  ['s_story', 6],
#  ['is_football', 6],
#  ['paketti', 6],
#  ['toy_story', 6],
#  ['casper_and', 6],
#  ['we_love', 6],
#  ['pes', 6],
#  ['looney_tunes', 6],
#  ['judge_dredd', 6],
#  ['leisure_suit', 6],
#  ['underminer', 6],
#  ['pandora_tomorrow', 6],
#  ['everybody_s', 6],
#  ['atv_offroad', 6],
#  ['seek_and', 6],
#  ['ps3', 6],
#  ['legacy_kain', 6],
#  ['casino_challenge', 6],
#  ['edition_remix', 6],
#  ['quake_iii', 6],
#  ['pinball', 6],
#  ['matrix_path', 6],
#  ['hot_wheels', 6],
#  ['steel', 6],
#  ['destroy', 6],
#  ['solid_snake', 5],
#  ['recon_2', 5],
#  ['men_black', 5],
#  ['jet_ion', 5],
#  ['hunter', 5],
#  ['rottatouille', 5],
#  ['garfield', 5],
#  ['spartan_total', 5],
#  ['dragonfly', 5],
#  ['jedi_starfighter', 5],
#  ['shadow_memories', 5],
#  ['kartta', 5],
#  ['quantum_solace', 5],
#  ['sopranos_road', 5],
#  ['fia_world', 5],
#  ['twist', 5],
#  ['sly_3', 5],
#  ['from_new', 5],
#  ['heroes_might', 5],
#  ['rapala_pro', 5],
#  ['angel_darkness', 5],
#  ['warfighter', 5],
#  ['espn_nhl', 5],
#  ['over_normandy', 5],
#  ['driver', 5],
#  ['acdc_live', 5],
#  ['06', 5],
#  ['giants_citizen', 5],
#  ['dance', 5],
#  ['l', 5],
#  ['espn_nba', 5],
#  ['adventure', 5],
#  ['o_rama', 5],
#  ['mx_vs', 5],
#  ['hammers', 5],
#  ['mummy_returns', 5],
#  ['ghost_rider', 5],
#  ['lemony_snicket', 5],
#  ['2001', 5],
#  ['club', 5],
#  ['eragon', 5],
#  ['generation', 5],
#  ['shrek_kolmas', 5],
#  ['kabuto', 5],
#  ['soccer_5', 5],
#  ['cum_laude', 5],
#  ['pop_idol', 5],
#  ['terminator_3', 5],
#  ['commandos_2', 5],
#  ['street_racing', 5],
#  ['ii_alien', 5],
#  ['web_shadows', 5],
#  ['spirit_dancer', 5],
#  ['england_international', 5],
#  ['warrior_ten', 5],
#  ['adventures', 5],
#  ['nfl_street', 5],
#  ['rise_machines', 5],
#  ['wrc_4', 5],
#  ['japani', 5],
#  ['atelier_iris', 5],
#  ['heaven', 5],
#  ['safari_adventures', 5],
#  ['team_racing', 5],
#  ['peliä', 5],
#  ['it_high', 5],
#  ['fifa_2005', 5],
#  ['scene_investigation', 5],
#  ['disney_bolt', 5],
#  ['wallace_and', 5],
#  ['space_chimps', 5],
#  ['island', 5],
#  ['from_russia', 5],
#  ['stock_car', 5],
#  ['wardrobe', 5],
#  ['with', 5],
#  ['destruction_derby', 5],
#  ['valken', 5],
#  ['v_rally', 5],
#  ['machines', 5],
#  ['sims_bustin', 5],
#  ['koiran_elämää', 5],
#  ['big_game', 5],
#  ['disney_pirates', 5],
#  ['alliance', 5],
#  ['bowling_2006', 5],
#  ['musical_3', 5],
#  ['2nd_runner', 5],
#  ['monopoly', 5],
#  ['babe', 5],
#  ['victorious_boxers', 5],
#  ['cell_pandora', 5],
#  ['fallout_brotherhood', 5],
#  ['rainbow_six', 5],
#  ['pelkkä_levy', 5],
#  ['tenchu_wrath', 5],
#  ['jim', 5],
#  ['soccer_2009', 5],
#  ['flintstones_bedrock', 5],
#  ['skies', 5],
#  ['shin_megami', 5],
#  ['one_lives', 5],
#  ['spyro_enter', 5],
#  ['socom_us', 5],
#  ['starsky_hutch', 5],
#  ['dark', 5],
#  ['shadow_colossus', 5],
#  ['battle', 5],
#  ['year', 5],
#  ['scooby_doo', 5],
#  ['smash_up', 5],
#  ['3_lemoon', 5],
#  ['gromit_curse', 5],
#  ['fishing', 5],
#  ['athens_2004', 5],
#  ['evil_dead', 5],
#  ['ghostbusters_video', 5],
#  ['pes_2008', 5],
#  ['road_rage', 5],
#  ['secret_weapons', 5],
#  ['dead_eye', 5],
#  ['csi_crime', 5],
#  ['crash_tag', 5],
#  ['happy_feet', 5],
#  ['warriors_orochi', 5],
#  ['ghost_hunter', 5],
#  ['superman_returns', 5],
#  ['sly_raccoon', 5],
#  ['ford_street', 5],
#  ['hummer_badlands', 5],
#  ['brave_search', 5],
#  ['tekken_5', 5],
#  ['eyetoy_kinetic', 5],
#  ['legend_spyro', 5],
#  ['respect', 5],
#  ['dino_thunder', 5],
#  ['flatout', 5],
#  ['dead_alive', 5],
#  ['eyetoy_groove', 5],
#  ['italian_job', 5],
#  ['castle_shikigami', 5],
#  ['were_rabbit', 5],
#  ['larry_magna', 5],
#  ['devil_kings', 5],
#  ['catwoman', 5],
#  ['eater', 5],
#  ['ultimate', 4],
#  ['men_courage', 4],
#  ['war', 4],
#  ['ohjeineen', 4],
#  ['lockdown', 4],
#  ['s_series', 4],
#  ['crouching_tiger', 4],
#  ['nascar_08', 4],
#  ['quack_attack', 4],
#  ['buzz_music', 4],
#  ['wanted', 4],
#  ['socom', 4],
#  ['horsez', 4],
#  ['cry', 4],
#  ['horror_predators', 4],
#  ['ferrari_f355', 4],
#  ['gta_vice', 4],
#  ['3_dimensions', 4],
#  ['fight_ny', 4],
#  ['pes_3', 4],
#  ['serious_sam', 4],
#  ['european_tennis', 4],
#  ['spy_hunter', 4],
#  ['lemmikkielämää', 4],
#  ['next_encounter', 4],
#  ['battlefront', 4],
#  ['evil_twin', 4],
#  ['destiny', 4],
#  ['space_channel', 4],
#  ['eternal', 4],
#  ['mania', 4],
#  ['3_ja', 4],
#  ['myst_iii', 4],
#  ['hitman_contracts', 4],
#  ['vs_death', 4],
#  ['2006_fifa', 4],
#  ['endgame', 4],
#  ['turok_evolution', 4],
#  ['series_unfortunate', 4],
#  ['two_thrones', 4],
#  ['with_love', 4],
#  ['12', 4],
#  ['soulcalibur_3', 4],
#  ['syberia', 4],
#  ['sing_star', 4],
#  ['edit', 4],
#  ['prostroke_golf', 4],
#  ['official_game', 4],
#  ['offroad_extreme', 4],
#  ['motogp4', 4],
#  ['assault_suit', 4],
#  ['international_cue', 4],
#  ['out', 4],
#  ['naruto_uzumaki', 4],
#  ['metal_slug', 4],
#  ['america_s', 4],
#  ['yakuza_fury', 4],
#  ['battlestar_galactica', 4],
#  ['10_most', 4],
#  ['22', 4],
#  ['battlefront_ii', 4],
#  ['disgaea_hour', 4],
#  ['nba', 4],
#  ['auto', 4],
#  ['ant_bully', 4],
#  ['fighting_angels', 4],
#  ['alien_force', 4],
#  ['s_rainbow', 4],
#  ['game_collection', 4],
#  ['disney_move', 4],
#  ['red_one', 4],
#  ['monster_trux', 4],
#  ['rc_toy', 4],
#  ['caribbean_world', 4],
#  ['outbreak', 4],
#  ['soccer_4', 4],
#  ['ace_action', 4],
#  ['drive_collection', 4],
#  ['top_trumps', 4],
#  ['fistful_boomstick', 4],
#  ['extreme_freeride', 4],
#  ['canis_canem', 4],
#  ['usa', 4],
#  ['simpsons_hit', 4],
#  ['ultimate_board', 4],
#  ['spyhunter', 4],
#  ['murder', 4],
#  ['ferrari_challenge', 4],
#  ['b_boy', 4],
#  ['smugglers_run', 4],
#  ['obscure', 4],
#  ['herdy_gerdy', 4],
#  ['roborumble', 4],
#  ['rayman_revolution', 4],
#  ['supernova', 4],
#  ['nhl_2k7', 4],
#  ['31', 4],
#  ['rygar_legendary', 4],
#  ['dragon', 4],
#  ['astro_zoo', 4],
#  ['world_cup', 4],
#  ['shield_game', 4],
#  ['pal_sealed', 4],
#  ['l_heist', 4],
#  ['man', 4],
#  ['shrek_3', 4],
#  ['tiger', 4],
#  ['devil_saga', 4],
#  ['came_from', 4],
#  ['poker', 4],
#  ['night', 4],
#  ['2k5', 4],
#  ['amf_xtreme', 4],
#  ['project_snowblind', 4],
#  ['rage', 4],
#  ['disney_g', 4],
#  ['bionicle', 4],
#  ['super', 4],
#  ['size_matters', 4],
#  ['hidden_dragon', 4],
#  ['jalkapallo', 4],
#  ['fallen', 4],
#  ['cartoon_network', 4],
#  ['destroy_all', 4],
#  ['super_monkey', 4],
#  ['disney_up', 4],
#  ['exile', 4],
#  ['spirits', 4],
#  ['humans_2', 4],
#  ['cold_winter', 4],
#  ['perfect_ace', 4],
#  ['mission_las', 4],
#  ['destruction', 4],
#  ['fusion', 4],
#  ['summoner_2', 4],
#  ['events', 4],
#  ['disney_golf', 4],
#  ['transformers_revenge', 4],
#  ['sega_mega', 4],
#  ['rocky', 4],
#  ['digimon_world', 4],
#  ['tomorrow', 4],
#  ['mr_bean', 4],
#  ['tak_and', 4],
#  ['ico', 4],
#  ['extermination', 4],
#  ['unreal_tournament', 4],
#  ['world_series', 4],
#  ['hugo_cannoncruise', 4],
#  ['25', 4],
#  ['swords_destiny', 4],
#  ['s_revenge', 4],
#  ['rogue_galaxy', 4],
#  ['2_big', 4],
#  ['dragon_quest', 4],
#  ['shaun_white', 4],
#  ['fighting', 4],
#  ['down', 4],
#  ['trofeo_pirelli', 4],
#  ['freak_out', 4],
#  ['tekken_4', 4],
#  ['katso', 4],
#  ['lemoon_twist', 4],
#  ['space_invaders', 4],
#  ['joe_rise', 4],
#  ['disneyn_aarreplaneetta', 4],
#  ['catz', 4],
#  ['princess', 4],
#  ['vendetta', 4],
#  ['make_soccer', 4],
#  ['shaolin_monks', 4],
#  ['x_treme', 4],
#  ['play_it', 4],
#  ['lemmings', 4],
#  ['wild_wild', 4],
#  ['monster_vs', 4],
#  ['total_club', 4],
#  ['4_playstation', 4],
#  ['senior_year', 4],
#  ['pelipaketti', 4],
#  ['stealth_force', 4],
#  ['tensei_digital', 4],
#  ['battles', 4],
#  ['world_championship', 4],
#  ['legends', 4],
#  ['nhl_2k6', 4],
#  ['dalmatians_3', 4],
#  ['world_wrestling', 4],
#  ['hulk', 4],
#  ['raw_2010', 4],
#  ['g_i', 4],
#  ['x2', 4],
#  ['midway_arcade', 4],
#  ['vegum', 4],
#  ['jacked', 3],
#  ['simpsons_road', 3],
#  ['bushido', 3],
#  ['die_hard', 3],
#  ['capcom_classics', 3],
#  ['barbarian', 3],
#  ['metallica', 3],
#  ['next_door', 3],
#  ['pelit_käytetyt', 3],
#  ['skater_3', 3],
#  ['fury_4', 3],
#  ['motogp3', 3],
#  ['age_empires', 3],
#  ['nba_2k9', 3],
#  ['garfield_lasagna', 3],
#  ['mega_man', 3],
#  ['open_season', 3],
#  ['doom', 3],
#  ['one', 3],
#  ['world_war', 3],
#  ['salt_lake', 3],
#  ['motogp', 3],
#  ['autiosaari_playstation', 3],
#  ['scare_school', 3],
#  ['cronicles_narnia', 3],
#  ['arc_twilight', 3],
#  ['black_kat', 3],
#  ['return_king', 3],
#  ['marvel_ultimate', 3],
#  ['f1_04', 3],
#  ['deadly_strike', 3],
#  ['battle_volcano', 3],
#  ['mtv_pimp', 3],
#  ['suffering_ties', 3],
#  ['pipe_mania', 3],
#  ['2_wolverine', 3],
#  ['41', 3],
#  ['knockout_kings', 3],
#  ['furious', 3],
#  ['evil', 3],
#  ['defiance', 3],
#  ['fifa_11', 3],
#  ['ps1', 3],
#  ['187_ride', 3],
#  ['2_meltdown', 3],
#  ['protector_earth', 3],
#  ['heroes', 3],
#  ['spyro_hero', 3],
#  ['go_kart', 3],
#  ['family_guy', 3],
#  ['street', 3],
#  ['levy', 3],
#  ['omega_strain', 3],
#  ['rumble_racing', 3],
#  ['raiteille_platinum', 3],
#  ['star', 3],
#  ['mummy', 3],
#  ['express', 3],
#  ['ex', 3],
#  ['platinum_playstation', 3],
#  ['dancingstage_supernova', 3],
#  ['ratatouille', 3],
#  ['xena_warrior', 3],
#  ['i_d', 3],
#  ['arena', 3],
#  ['pdc_world', 3],
#  ['bomberman_hardball', 3],
#  ['final', 3],
#  ['fame_academy', 3],
#  ['army_men', 3],
#  ['off_road', 3],
#  ['sing_it', 3],
#  ['soccer_pes', 3],
#  ['tom', 3],
#  ['ultimate_spider', 3],
#  ['atv_untamed', 3],
#  ['madagascar', 3],
#  ['s_end', 3],
#  ['amazing_allies', 3],
#  ['operation_v', 3],
#  ['rampage_total', 3],
#  ['top_gun', 3],
#  ...]

# %%
# Initialize new columns for each word/bigram in dataframe

km_df3 = sentences.copy()
for item in bagofwords:
    km_df3[item] = 0

# %%
# VECTORIZE Bag of words dataframe
# The number of occurrences of a gram does not matter, only whether the words exists or not
# For example a title saying 'Star Wars 1, Part of Star Wars trilogy' does not make the title more "Star Wars-like"
# Than just "Star Wars 1".

for index,row in km_df3.iterrows():
    for word in row['bigrams']:
        km_df3.at[index, word] = 1

# %%
# Find counts of grams in the data

countsW = []
dropdf1 = km_df3.drop(['title','bigrams','links','currentPrice'],axis=1)
for key, item in dropdf1.iteritems():
    countsW.append([item.name,item.sum()])

# %%
# Sort the list to find the most common grams in data

countsW.sort(key = lambda i: i[1],reverse=True) 
countsW

# %%
# Drop columns that create noise in the data. These columns should not be basis for a cluster.

dropdf1 = dropdf1.drop(['ps_2','pal','playstation_2','platinum','b_pal','–','pal_sinetöity','play_station','ps_ii','video_game','game','trilogy','2_pelilevy','nro','pelit','hyvä','pelejä','muoveissa','harvinainen','suomiversio'],axis=1)

# %% [markdown]
# ## Clusterize the data with K-Means algorithm

# %%
# Number of clusters has been decided based on trying different amounts of clusters

n_clusters = 1650

hc = KMeans(n_clusters = n_clusters, max_iter =300, init = 'k-means++', n_init=1)
y_hc = hc.fit_predict(dropdf1)

# Test to see one cluster
for index, sentence in sentences.iterrows():
    if(y_hc[index] == 25):
#T        print(str(y_hc[index])+ ":" + str(sentence['title']))
# Out:
# 25:['singstar', 'r', 'b']
# 25:['shrek', 'third', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['ps', '2', 'singstar', 'r', 'b', 'pal']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b', '9405']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']
# 25:['singstar', 'r', 'b']

# %%
# Test to see first x clusters in the data

for index, sentence in sentences.iterrows():
    for jndex, jentence in sentences.iterrows():
        if(y_hc[jndex]==index):
                print(str(y_hc[jndex])+ ":" + str(jentence['title']))
    
    if index > 10:
        break
# Out:
# 0:['crash', 'nitro', 'kart', 'postikulun']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 1:['lego', 'batman', 'video', 'game']
# 2:['fight', 'night', 'round', '3']
# 2:['fight', 'night', 'round', '3']
# 2:['fight', 'night', 'round', '3']
# 2:['fight', 'night', 'round', '3']
# 2:['fight', 'night', 'round', '3']
# 2:['fight', 'night', 'round', '3']
# 2:['fight', 'night', 'round', '3', 'muoveissa']
# 2:['fight', 'night', 'round', '3']
# 2:['ps', '2', 'fight', 'night', 'round', '3', 'pal']
# 2:['fight', 'night', 'round', '3']
# 2:['fight', 'night', 'round', '3']
# 3:['star', 'wars', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 3:['star', 'wars', 'episode', 'iii', 'revenge', 'sith']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon', 'platinum', '8', '10']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['need', 'speed', 'carbon']
# 4:['ps', '2', 'need', 'speed', 'carbon', 'pal']
# 4:['need', 'speed', 'carbon']
# 5:['soulcalibur', '2']
# 5:['pes', '2']
# 5:['warriors', 'orochi', '2']
# 5:['castle', 'shikigami', '2']
# 5:['time', 'crisis', '2']
# 5:['vegas', 'casino', '2']
# 5:['ice', 'age', '2']
# 5:['midnight', 'club', '2']
# 5:['metropolismania', '2']
# 5:['warriors', 'orochi', '2']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell']
# 6:['tom', 'clancy', 's', 'splinter', 'cell', 'platinum']
# 7:['dragon', 'ball', 'z', 'budokai', '3']
# 7:['dragon', 'ball', 'z', 'budokai', '3']
# 7:['dragon', 'ball', 'z', 'budokai', '3']
# 7:['ps', '2', 'dragon', 'ball', 'z', 'budokai', '3', 'b', 'pal']
# 7:['dragon', 'ball', 'z', 'budokai', '3']
# 7:['dragon', 'ball', 'z', 'budokai', '3']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 8:['harry', 'potter', 'ja', 'liekehtivä', 'pikari']
# 9:['prince', 'persia', 'sands', 'time', 'platinum']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'playstation', '2', 'hyvä']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time', 'platinum', '10706']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time']
# 9:['prince', 'persia', 'sands', 'time']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii', 'ps', '2']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 10:['grand', 'theft', 'auto', 'iii']
# 11:['tiger', 'woods', 'pga', 'tour', '2003']
# 11:['tiger', 'woods', 'pga', 'tour', '06']
# 11:['tiger', 'woods', 'pga', 'tour', '2003']
# 11:['tiger', 'woods', 'pga', 'tour', '2003']

# %% [markdown]
# ## Enhance the clustering

# %%
# Find the most common label in clusters. The biggest class contains noise data: 
# items that are hard to clusterize for k-means algorithm.
# For example, items that contain multiple games, typos in title, rare games that only occur once in data.

from statistics import mode
noiseClass= mode(y_hc)
noiseClass
# Out:
# 62

# %%
# Add the labels to the dataframe

dropdf1['label']=y_hc

# %%
# Create a new DataFrame just for the noise data
# Save the old index, and reindex the dataframe for easier access

noises = dropdf1.loc[dropdf1['label']==noiseClass].copy()
noises['index1'] = noises.index
noises =noises.reset_index(drop=True)
noises['index1']
# Out:
# 0        80
# 1       142
# 2       151
# 3       202
# 4       224
#        ...
# 349    5991
# 350    6022
# 351    6024
# 352    6033
# 353    6037
# Name: index1, Length: 354, dtype: int64

# %%
# Try clusterizing the noise data again.
# This time, hierarchical clustering is used because data is divided into small clusters

n_clusters2 = int(len(noises)/1.25)

hc2 = AgglomerativeClustering(n_clusters = n_clusters2, affinity = 'euclidean', linkage = 'ward')

y_hc2 = hc2.fit_predict(noises.drop('index1',axis=1))

# %%
# Print the clusters in noise data for inspection.

i = 0
for index, sentence in noises.iterrows():
    for jndex, jentence in noises.iterrows():
        if(y_hc2[jndex]==index):
                print(str(y_hc2[jndex])+ ":" + str(sentences.at[jentence['index1'],'title']))
    
    if index > n_clusters2:
        break
# Out:
# 0:['pinball']
# 0:['powershot', 'pinball']
# 1:['007', 'nightfire']
# 1:['james', 'bond', '007', 'nightfire']
# 2:['gta', 'iii']
# 2:['gta', 'iii']
# 3:['just', 'cause']
# 3:['just', 'cause', '465']
# 4:['iridium', 'runners', '8591']
# 4:['iridium', 'runners']
# 5:['8kpl', 'pelejä']
# 6:['ico', 'pal']
# 6:['ico', 'pal']
# 7:['sky', 'odyssey']
# 7:['sky', 'odyssey', '11548']
# 8:['buzz', 'megavisa']
# 8:['buzz', 'megavisa']
# 9:['speed', 'racer']
# 9:['speed', 'racer']
# 10:['spytoy']
# 10:['spytoy', 'eye', 'toy']
# 11:['desert', 'storm', 'ps', '2', 'pell']
# 12:['celebrity', 'deathmarsh']
# 13:['vampire', 'night']
# 13:['vampire', 'night', 'ps', '2']
# 14:['forbidden', 'siren']
# 14:['forbidden', 'siren']
# 15:['makai', 'kingdom']
# 15:['makai', 'kingdom']
# 16:['singstar', 'take']
# 16:['singstar', 'take', 'harvinainen']
# 17:['iron', 'man']
# 17:['iron', 'man']
# 18:['powerdrome']
# 18:['powerdrome']
# 19:['dodgeball']
# 19:['dodgeball', 'pal']
# 20:['celebrity', 'deathmatch']
# 20:['celebrity', 'deathmatch']
# 21:['kultainen', 'kompassi']
# 21:['kultainen', 'kompassi']
# 22:['god', 'hand']
# 23:['radiata', 'stories', 'playstation', '2']
# 24:['thing']
# 25:['homerun']
# 26:['rolling', 'playstation', '2', 'käytetty']
# 27:['pelit', '6', 'kpl']
# 28:['tony', 'hawk´s', 'project', '8']
# 29:['off', 'road']
# 29:['off', 'road']
# 30:['clumsy', 'shumsy']
# 30:['clumsy', 'shumsy']
# 31:['swat', 'siege']
# 31:['swat', 'siege']
# 32:['grandia', 'ii']
# 32:['grandia', 'ii']
# 33:['home', 'alone']
# 33:['home', 'alone']
# 34:['silent', 'scope']
# 34:['silent', 'scope']
# 35:['thrillville']
# 35:['thrillville']
# 36:['sword', 'samurai']
# 36:['sword', 'samurai', 'playstation', '2']
# 37:['mystic', 'heroes']
# 37:['mystic', 'heroes']
# 38:['paddington', 'bear']
# 38:['paddington', 'bear']
# 39:['defender']
# 39:['defender']
# 40:['daemon', 'summoner']
# 40:['daemon', 'summoner']
# 41:['transworld', 'surf']
# 41:['transworld', 'surf']
# 42:['xiaolin', 'showdown']
# 42:['xiaolin', 'showdown', 'playstation', '2']
# 43:['worms', 'blast']
# 43:['worms', 'blast']
# 44:['madden', 'nfl', '2002']
# 45:['wild', 'arms', '3', 'pal']
# 46:['despicable', 'me']
# 47:['ps', '2', 'nba', '2k11', 'pal']
# 48:['homura']
# 49:['ps', '2', 'karaoke', 'stage', 'pal']
# 50:['tourist', 'trophy']
# 51:['transformers']
# 52:['gift']
# 53:['commandos', '2']
# 54:['transformer']
# 55:['disgaea', '2']
# 56:['paavo', 'pesusieni']
# 57:['demolevyt', '4', 'kpl']
# 58:['espn', 'nba', 'basketball']
# 59:['trapt', 'harvinainen']
# 59:['trapt']
# 60:['oni']
# 60:['oni']
# 61:['gladius']
# 61:['gladius']
# 62:['ps', '2', 'nba', 'live', '2005', 'b', 'pal']
# 63:['evil', 'dead', 'playstation', 'pelit']
# 64:['my', 'street']
# 64:['my', 'street', 'ps', 'ii']
# 65:['trivial', 'pursuit']
# 65:['trivial', 'pursuit']
# 66:['dark', 'cloud']
# 66:['dark', 'cloud']
# 67:['dragon', 'rage']
# 68:['eyetoy', 'kinetic']
# 68:['eyetoy', 'kinetic']
# 69:['search', 'destroy']
# 69:['search', 'destroy']
# 70:['hulk', 'platinum']
# 70:['hulk', 'platinum']
# 71:['call', 'duty', 'trilogy', 'boxi']
# 72:['headhunter']
# 72:['headhunter']
# 73:['sniper', 'elite']
# 73:['sniper', 'elite']
# 74:['megaman', 'x8']
# 74:['megaman', 'x8']
# 75:['eternal', 'quest']
# 75:['eternal', 'quest']
# 76:['warriors']
# 76:['warriors']
# 77:['madden', '2001']
# 77:['madden', '2001']
# 78:['truck', 'racer']
# 78:['truck', 'racer', 'ps', '2']
# 79:['barbie', 'island', 'princessps2']
# 80:['kessen']
# 80:['kessen']
# 81:['lotus', 'challenge']
# 82:['kessen', 'iii']
# 82:['kessen', 'iii']
# 83:['incredibles']
# 83:['incredibles']
# 84:['eternal', 'ring']
# 84:['eternal', 'ring']
# 85:['constantine']
# 85:['constantine']
# 86:['code', 'samurai']
# 86:['code', 'samurai', 'ps', 'ii']
# 87:['ps', '2', 'pelit', 'x', '8']
# 88:['fighting', 'angelsps2']
# 89:['unlimited', 'saga']
# 90:['formula', 'one', '2005']
# 91:['hugo', 'pelit', '5', 'kpl', 'ps', '2']
# 92:['eye', 'toy', 'play']
# 93:['ps', '2', 'gta', '3', 'pal']
# 94:['formula', 'challenge']
# 95:['nba', '08']
# 96:['gt', 'r', '400']
# 97:['crisis', 'zone']
# 98:['drakan']
# 99:['resident', 'evil', '4', 'suomiversio']
# 100:['pelejä', '6kpl']
# 101:['lassie']
# 102:['vegas', 'casino']
# 103:['leaderboard', 'golf']
# 104:['ps', '2', 'gun', 'pal']
# 105:['suffering']
# 106:['mambo']
# 107:['evergrace']
# 108:['aeon', 'flux']
# 109:['gudfadern']
# 110:['futurama']
# 111:['punisher']
# 112:['cricket', '2005']
# 113:['phantom', 'brave']
# 114:['onimusha', '2']
# 115:['ps', '2', 'pelejä', '3kpl']
# 116:['cronicles', 'narnia', 'ps', '2']
# 117:['play', 'station', '2', 'pelilevy', 'nro', '69']
# 118:['sx', 'superstar']
# 119:['rayman', 'setti']
# 120:['xtreme', 'cheats']
# 121:['cartoon', 'kingdom']
# 122:['pelejä']
# 122:['pelit']
# 122:['pelejä']
# 122:['pelit']
# 122:['pelit']
# 122:['pelit']
# 122:['pelit']
# 123:['cat', 'hat']
# 124:['breath', 'fire', 'dragon', 'quarter', 'pal']
# 125:['new', 'york', 'race']
# 126:['demolition', 'girlps2']
# 127:['moto', 'gp3', 'platinum']
# 128:['cricket', '2002']
# 129:['age', 'empires', 'age', 'kings']
# 130:['maze', 'action']
# 130:['maze', 'action', 'ps', 'ii']
# 131:['ps', '2', 'rhytmic', 'star', 'pal']
# 132:['hitman', '–', 'contracts']
# 133:['dj', 'vendetta']
# 134:['cool', 'shot']
# 134:['cool', 'shot']
# 135:['darkwatch', 'promo']
# 136:['grazy', 'golf']
# 137:['soldier', 'fortune', '464']
# 138:['project', 'eden']
# 138:['project', 'eden']
# 139:['mxrider', '10256']
# 140:['playboy', 'mansion']
# 141:['red', 'baron']
# 142:['onimusha', '3']
# 142:['onimusha', '3']
# 143:['ace', 'lightning']
# 144:['ps', '2', 'reel', 'fishing', '3', 'pal']
# 145:['death', 'degrees']
# 146:['7', 'blades']
# 146:['7', 'blades']
# 147:['g', 'surfers']
# 148:['midnight', 'club', 'street', 'racing']
# 149:['nascar', '09', 'playstation', '2']
# 150:['test', 'drive']
# 151:['doomsday', 'racers']
# 152:['tenchu', '–', 'wrath', 'heaven']
# 153:['dark', 'summit']
# 154:['eyetoy', 'chat']
# 155:['puzzle', 'quest']
# 156:['kuri', 'kuri', 'mix']
# 157:['football', 'generation']
# 158:['dead', 'rights']
# 158:['dead', 'rights']
# 159:['sonic', 'unleashed', '12217']
# 160:['eye', 'toy', 'astro', 'zoo']
# 161:['urban', 'reign']
# 162:['dance', 'factory']
# 162:['dance', 'factory']
# 163:['caspers', 'scare', 'school', 'pal', 'sinetöity']
# 164:['hack', 'infection']
# 165:['007', 'quantum', 'solace']
# 166:['total', 'overdose']
# 166:['ps', '2', 'total', 'overdose', 'b', 'pal']
# 167:['csi', 'dimensions', 'murder']
# 168:['battle', 'bacific']
# 169:['evil', 'may', 'cry']
# 170:['charlottes', 'web']
# 170:['charlottes', 'web']
# 171:['mega', 'man', 'x8']
# 172:['spiderwick', 'cronicles']
# 173:['singsta', 'pop', 'hits']
# 174:['persona', '3', 'fes']
# 175:['slim', 'virtalähde']
# 176:['cold', 'fear']
# 177:['crusty', 'demons', 'pal', 'sinetöity']
# 178:['eyetoy', 'kamera']
# 179:['impossible', 'mission']
# 180:['crazyfrog', 'racer', '2']
# 181:['digital', 'devil', 'saga', '2']
# 182:['persona', '3', 'pal', 'sealed']
# 183:['teen', 'titans', 'pal', 'sinetöity']
# 184:['go', 'go', 'golf']
# 185:['incredible', 'hulk', '10599']
# 186:['fighting', 'fury']
# 187:['gungriffon', 'blaze']
# 188:['grazy', 'frog', 'racer']
# 189:['ex', 'zeus', 'pal', 'sinetöity']
# 190:['kidz', 'sports', 'basketball']
# 191:['smash', 'cars']
# 192:['knockout', 'kings', '2002']
# 193:['demolition', 'girl', 'playstation', '2']
# 194:['madden', '2004']
# 195:['eye', 'toy', 'chat']
# 196:['riding', 'star', '209']
# 197:['celtic', 'club', 'football']
# 198:['reel', 'fishing', 'iii']
# 199:['hardware', 'online', 'arena']
# 200:['fifa', '2004']
# 201:['epsn', 'nhl', 'hockey']
# 202:['robots']
# 203:['juiced', '2', '446']
# 204:['ratched', 'clank', '3']
# 205:['dog', 'island']
# 206:['little', 'britain', 'video', 'game']
# 207:['fast', 'and', 'furious']
# 208:['hidden', 'invasion']
# 209:['spy', 'hunter', '7462']
# 210:['ps', '2', 'juiced', 'pal']
# 211:['dancing', 'stage', 'max']
# 212:['mortal', 'kombat', 'armageddon']
# 213:['spyro', '–', 'dawn', 'dragon']
# 214:['castleween']
# 215:['astro', 'boy']
# 216:['ps', '2', 'pes', 'management', 'pal']
# 217:['ww2', 'tank', 'battles', 'hyvä']
# 218:['fahrenheit']
# 219:['strike', 'force', 'bowling']
# 220:['countryside', 'bears']
# 221:['bust', 'bloc']
# 222:['play', 'station', '2', 'pelilevy', 'nro', '18']
# 223:['leisure', 'suit', 'larry']
# 224:['narnia', 'prince', 'caspian']
# 225:['twenty', 'party', 'playstation', '2']
# 226:['burnout', '3']
# 227:['ferrari', 'f355', 'challange']
# 228:['sled', 'storm']
# 229:['puzzle', 'buzzle', 'veroinen']
# 230:['indycar', 'series']
# 231:['lord', 'ring', 'third', 'age']
# 232:['monster', 'hunter']
# 233:['surfing', 'h30']
# 234:['play', 'station', '2', 'pelilevy', 'nro', '44']
# 235:['dancingstage', 'super', 'nova', '2']
# 236:['top', 'gun', 'ps', '2']
# 237:['frendit', 'ps', '2']
# 238:['play', 'sports']
# 239:['metropolismania', 'ps', 'ii']
# 240:['bouncer']
# 241:['area', '51']
# 242:['play', 'station', '2', 'pelilevy', 'nro', '45']
# 243:['shox']
# 244:['play', 'station', '2', 'pelilevy', 'nro', '16']
# 245:['play', 'station', '2', 'pelilevy', 'nro', '60']
# 246:['kessen', '2']
# 247:['shadow', 'zorro']
# 248:['nemoa', 'etsimässä']
# 249:['play', 'station', '2', 'pelilevy', 'nro', '19']
# 250:['play', 'station', '2', 'pelilevy', 'nro', '39']
# 251:['play', 'station', '2', 'pelilevy', 'nro', '68']
# 252:['hitman', '2']
# 253:['xiii']
# 254:['psi', 'ops']
# 255:['ssx']
# 256:['f1', '06']
# 257:['ps', '2', 'motogp', 'pal']
# 258:['kinetic', 'combat']
# 259:['red', 'ninja']
# 260:['fantavision', 'pal']
# 261:['play', 'station', '2', 'pelilevy', 'nro', '22']
# 262:['nhl', '2k8', 'playstation', '2']
# 263:['robocop']
# 264:['speed', 'challenge']
# 265:['king', 'arthur']
# 266:['captain', 'scarlett']
# 267:['mojo', 'pal']
# 268:['play', 'station', '2', 'pelilevy', 'nro', '48']
# 269:['driven']
# 270:['arcade']
# 271:['pipemania', 'playstation', '2']
# 272:['play', 'station', '2', 'pelilevy', 'nro', '66']
# 273:['amplitude']
# 274:['bombastic']
# 275:['play', 'station', '2', 'pelilevy', 'nro', '54']
# 276:['g', 'force']
# 277:['play', 'station', '2', 'pelilevy', 'nro', '78']
# 278:['dogeball', 'playstation', '2']
# 279:['play', 'station', '2', 'pelilevy', 'nro', '41']
# 280:['play', 'station', '2', 'pelilevy', 'nro', '49']
# 281:['zapper', 'playstation', '2']
# 282:['test', 'drive', 'unlimited']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier

# The noise class actually contained items that belong in a cluster that was already made.
# Create a regression model to try to fit these items in the clusters
# After trial, logistic regression seems to work the best.

logReg = LogisticRegression()

linReg = LinearRegression()

rfc = RandomForestClassifier(n_estimators=100)

classModel = logReg

# %%
# Subset data: train with data that has labels that are not the biggest cluster
# Fit the data into model

fitdf = dropdf1.loc[dropdf1['label']!=noiseClass]

classifier = classModel.fit(fitdf.drop('label',axis=1),fitdf['label'])
# Out:
# C:\Users\tipe_\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tipe_\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
# Find predictions for the noise items

noisePreds= classModel.predict(noises.drop(['index1','label','bestPred','bestAcc'],axis=1))

# %%
# The model cannot predict everything correctly, because not all data has a predetermined cluster
# This is indicated with data being predicted wrongly into a single cluster

wrongPred = mode(noisePreds)
wrongPred
# Out:
# 43

# %%
# Find the good predictions, and store the target cluster and prediction accuracy

# Regression model has been trained with all other classes than the noise class.
# The scores variable is just a list of scores for each label that was given in the regression model fit function.
# So, all indexes in scores that are bigger than the noise class number are off by one.
# To fix this error, pred must be one smaller if it is bigger than the noise class when checking the best score.
 
minlim = 0.00001
maxlim = 0.06

goodPreds = []
for index, row in noises.iterrows():   
    t_x = noises.drop(['index1','label','bestPred','bestAcc'],axis=1).loc[[index]]
    pred = noisePreds[index]        
    scores = classifier.predict_proba(t_x)
    
    if pred >= noiseClass:
        bestScore = scores[0][pred-1]
    else:
        bestScore = scores[0][pred]
        
    if (bestScore >= minlim)& (bestScore<maxlim) &(pred!= wrongPred):
        goodPreds.append([index,pred,bestScore])
        print("Accuracy: " + str(bestScore))
        print(pred)
# Out:
# Accuracy: 0.011316124733541252
# 406
# Accuracy: 0.001446817445093634
# 1451
# Accuracy: 0.0014223935159845675
# 1404
# Accuracy: 0.021259731386006592
# 263
# Accuracy: 0.0014468174450936273
# 1601
# Accuracy: 0.006930792142419627
# 456
# Accuracy: 0.0014468174450936273
# 1559
# Accuracy: 0.012807307807268105
# 154
# Accuracy: 0.001217795330961697
# 244
# Accuracy: 0.004467082112682401
# 1036
# Accuracy: 0.0012989189155681446
# 524
# Accuracy: 0.0014216657647251423
# 1333
# Accuracy: 0.002813051884957945
# 617
# Accuracy: 0.0012989216419338832
# 1059
# Accuracy: 0.0014162713174661445
# 331
# Accuracy: 0.0038664379543693022
# 1217
# Accuracy: 0.0014162713174661445
# 331
# Accuracy: 0.009110395367366667
# 402
# Accuracy: 0.007252629242894306
# 663
# Accuracy: 0.003160164568834006
# 421
# Accuracy: 0.010083245855667894
# 245
# Accuracy: 0.0012989216419338832
# 1059
# Accuracy: 0.0013616149235995468
# 1129
# Accuracy: 0.004173510169827388
# 148
# Accuracy: 0.007027239017674773
# 67
# Accuracy: 0.0013720598487197131
# 798
# Accuracy: 0.0013722053399859307
# 1225
# Accuracy: 0.0021813129079852164
# 280
# Accuracy: 0.0014427172373663519
# 1470
# Accuracy: 0.010073181833505874
# 245
# Accuracy: 0.0037037768216301734
# 500
# Accuracy: 0.0014167004552043856
# 582
# Accuracy: 0.0013711998724436133
# 930
# Accuracy: 0.006000069413999881
# 495
# Accuracy: 0.002827990067732964
# 703
# Accuracy: 0.0013710749728779506
# 1104
# Accuracy: 0.011452110712878744
# 394
# Accuracy: 0.003864380819410555
# 939
# Accuracy: 0.0014210142829184675
# 1280
# Accuracy: 0.0014221685039407465
# 1314
# Accuracy: 0.001302939020990455
# 727
# Accuracy: 0.014162047578813834
# 236
# Accuracy: 0.001418276566266065
# 1314
# Accuracy: 0.0019076794334011403
# 395
# Accuracy: 0.0013726234940774696
# 766
# Accuracy: 0.001421283372191978
# 1011
# Accuracy: 0.0014405379420707218
# 1508
# Accuracy: 0.003864380819410555
# 940
# Accuracy: 0.0012989123147877258
# 806
# Accuracy: 0.011368628116078746
# 324
# Accuracy: 0.0036448096930750957
# 952
# Accuracy: 0.001433918600109343
# 1586
# Accuracy: 0.001636323269982022
# 300
# Accuracy: 0.021316505213856366
# 84
# Accuracy: 0.0013729004381998907
# 1191
# Accuracy: 0.0013731048867557801
# 975
# Accuracy: 0.013053095897353612
# 210
# Accuracy: 0.001043324306251911
# 154
# Accuracy: 0.0013007721552907837
# 1262
# Accuracy: 0.011305634224073666
# 406
# Accuracy: 0.012474873287252634
# 318
# Accuracy: 0.006215678832044447
# 159
# Accuracy: 0.003864380819410555
# 795
# Accuracy: 0.001636323269982022
# 300
# Accuracy: 0.0013702003092022946
# 573
# Accuracy: 0.0014098964933404495
# 1423
# Accuracy: 0.0015991818621869781
# 48
# Accuracy: 0.0014190759495326414
# 990
# Accuracy: 0.0012225291831448714
# 1067
# Accuracy: 0.006914533242769021
# 599
# Accuracy: 0.0015246429840483841
# 351
# Accuracy: 0.0015785583951406672
# 95
# Accuracy: 0.0013627491103864176
# 587
# Accuracy: 0.0014399604223452572
# 1631
# Accuracy: 0.003864380819410555
# 851
# Accuracy: 0.0014180187668310004
# 1551
# Accuracy: 0.011080972728402893
# 406
# Accuracy: 0.0026906082023544524
# 490
# Accuracy: 0.007248577042736591
# 113
# Accuracy: 0.0014173167193523596
# 1195
# Accuracy: 0.002808675695256231
# 518
# Accuracy: 0.0017310655818382887
# 5
# Accuracy: 0.01720023514008179
# 406
# Accuracy: 0.003864380819410555
# 781
# Accuracy: 0.0011373723613739405
# 749
# Accuracy: 0.003011923244109245
# 679
# Accuracy: 0.00788984996455631
# 163
# Accuracy: 0.003830622764531529
# 516
# Accuracy: 0.001429670037755144
# 1544
# Accuracy: 0.0013000154153189375
# 754
# Accuracy: 0.0014223935159845675
# 1231
# Accuracy: 0.0013627491103864176
# 587
# Accuracy: 0.0014421293418012229
# 1304
# Accuracy: 0.0013708665601290808
# 945
# Accuracy: 0.018896812776553154
# 128
# Accuracy: 0.0014462463111503934
# 1561
# Accuracy: 0.004134983591179819
# 148
# Accuracy: 0.0014123548562460773
# 1106
# Accuracy: 0.003830622764531529
# 516
# Accuracy: 0.011247684223820264
# 406
# Accuracy: 0.0017122978157070661
# 5
# Accuracy: 0.008913360683726586
# 389
# Accuracy: 0.014900485288516757
# 226
# Accuracy: 0.001430140927054757
# 1544
# Accuracy: 0.0013716826533084234
# 762
# Accuracy: 0.0015785583951406672
# 95
# Accuracy: 0.0014195001961333368
# 1210
# Accuracy: 0.006012613660740898
# 495
# Accuracy: 0.001298471946383192
# 1042
# Accuracy: 0.018927570905219827
# 75
# Accuracy: 0.0014216911587205405
# 1519
# Accuracy: 0.0014464756356557871
# 1052
# Accuracy: 0.016807267557443092
# 85
# Accuracy: 0.003864380819410555
# 918
# Accuracy: 0.0014123548562460773
# 1106
# Accuracy: 0.001285122322592737
# 723
# Accuracy: 0.0013625724273756835
# 894
# Accuracy: 0.0014051676294311495
# 1341
# Accuracy: 0.0016266107038710948
# 662
# Accuracy: 0.015292006354768031
# 230
# Accuracy: 0.0016631242466955652
# 1236
# Accuracy: 0.0013691238031692358
# 1149
# Accuracy: 0.007179912597707362
# 589
# Accuracy: 0.0013723989956249034
# 830
# Accuracy: 0.010381284603331792
# 91
# Accuracy: 0.0014223935159845675
# 1231
# Accuracy: 0.0013723989956249034
# 830
# Accuracy: 0.010274227837339299
# 451
# Accuracy: 0.0014096984216404912
# 1202
# Accuracy: 0.003871036111397532
# 717
# Accuracy: 0.001430140927054757
# 1544
# Accuracy: 0.0014457920835415636
# 1569
# Accuracy: 0.007179912597707362
# 589
# Accuracy: 0.001704808294593314
# 24
# Accuracy: 0.0014180187668310004
# 1551
# Accuracy: 0.0014461330921436625
# 1581
# Accuracy: 0.001371186703069472
# 750
# Accuracy: 0.0067113926603021064
# 586
# Accuracy: 0.001298471946383192
# 1042
# Accuracy: 0.005080005410163618
# 147
# Accuracy: 0.01579100872693494
# 150
# Accuracy: 0.0014223935159845675
# 1117
# Accuracy: 0.0014217243715860357
# 1208
# Accuracy: 0.0016554050045650569
# 5
# Accuracy: 0.009095595142888331
# 622
# Accuracy: 0.007208078162782172
# 829
# Accuracy: 0.0012985329513421557
# 626
# Accuracy: 0.0013727710097110764
# 744
# Accuracy: 0.010243157258052726
# 382
# Accuracy: 0.00349726704218078
# 800
# Accuracy: 0.0014464653786233532
# 1526
# Accuracy: 0.003383365952228431
# 828
# Accuracy: 0.001446489739376345
# 1560
# Accuracy: 0.0014123548562460773
# 1557
# Accuracy: 0.0014223935159845675
# 1170
# Accuracy: 0.0014464756356557871
# 1052
# Accuracy: 0.001421599286186655
# 1345
# Accuracy: 0.013063679798990396
# 210
# Accuracy: 0.016883796027494107
# 160
# Accuracy: 0.005986874183200796
# 495
# Accuracy: 0.011711278962504927
# 394

# %%
# Print each "good" prediction, as well as all other items that were clustered in the same cluster in the hierarchical clustering
# And print the items in the predicted target cluster

for i,row in enumerate(goodPreds):
    print("----------------------------------")
    print("")
    print("Originals as noise, names: ")
    
    for j,row2 in enumerate(goodPreds):
        if (row2[1] == row[1]):
            print(str(sentences.at[noises.at[row2[0],'index1'],'title']))
        
    print("Would be reclassified into: " + str(row[1]))
    print("With accuracy: " + str(row[2]))
    print("Items in this cluster are: ")


    # test to see one cluster
    for index, sentence in sentences.iterrows():
        if(y_hc[index] == row[1]):                
            print(str(y_hc[index])+ ":" + str(sentence['bigrams']))
# Out:
# ----------------------------------
#
# Originals as noise, names:
# ['eye', 'toy', 'chat']
# ['spytoy', 'eye', 'toy']
# ['eye', 'toy', 'play']
# ['play', 'sports']
# ['eye', 'toy', 'astro', 'zoo']
# Would be reclassified into: 406
# With accuracy: 0.011316124733541252
# Items in this cluster are:
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# ----------------------------------
#
# Originals as noise, names:
# ['dancingstage', 'super', 'nova', '2']
# Would be reclassified into: 1451
# With accuracy: 0.001446817445093634
# Items in this cluster are:
# 1451:['dancingstage_super', 'nova']
# ----------------------------------
#
# Originals as noise, names:
# ['surfing', 'h30']
# Would be reclassified into: 1404
# With accuracy: 0.0014223935159845675
# Items in this cluster are:
# 1404:['sunny', 'garsia', 'surfing']
# ----------------------------------
#
# Originals as noise, names:
# ['lord', 'ring', 'third', 'age']
# Would be reclassified into: 263
# With accuracy: 0.021259731386006592
# Items in this cluster are:
# 263:['lord_rings', 'third_age']
# 263:['lord_rings', 'third_age']
# 263:['lord_rings', 'third_age']
# 263:['lord_rings', 'third_age']
# 263:['lord_rings', 'third_age']
# 263:['lord_rings', 'third_age']
# 263:['lord_rings', 'third_age']
# ----------------------------------
#
# Originals as noise, names:
# ['puzzle', 'buzzle', 'veroinen']
# Would be reclassified into: 1601
# With accuracy: 0.0014468174450936273
# Items in this cluster are:
# 1601:['jetix', 'puzzle_buzzle']
# ----------------------------------
#
# Originals as noise, names:
# ['ferrari', 'f355', 'challange']
# Would be reclassified into: 456
# With accuracy: 0.006930792142419627
# Items in this cluster are:
# 456:['ferrari_f355', 'challenge', '215']
# 456:['ferrari_f355', 'challenge']
# 456:['ferrari_f355', 'challenge']
# ----------------------------------
#
# Originals as noise, names:
# ['zapper', 'playstation', '2']
# Would be reclassified into: 1559
# With accuracy: 0.0014468174450936273
# Items in this cluster are:
# 1559:['zapper', '415']
# ----------------------------------
#
# Originals as noise, names:
# ['twenty', 'party', 'playstation', '2']
# ['play', 'station', '2', 'pelilevy', 'nro', '39']
# Would be reclassified into: 154
# With accuracy: 0.012807307807268105
# Items in this cluster are:
# 154:['twenty_2', 'party']
# 154:['twenty_2', 'party']
# 154:['twenty_2', 'party']
# 154:['twenty_2', 'party', '39']
# 154:['twenty_2', 'party']
# 154:['ps_2', 'twenty_2', 'party', 'pal']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '41']
# Would be reclassified into: 244
# With accuracy: 0.001217795330961697
# Items in this cluster are:
# 244:['monster_trux', 'arenas_special', 'edition', '41', '872', 'k']
# ----------------------------------
#
# Originals as noise, names:
# ['leisure', 'suit', 'larry']
# Would be reclassified into: 1036
# With accuracy: 0.004467082112682401
# Items in this cluster are:
# 1036:['leisure_suit', 'larry_magna', 'cum_laude']
# 1036:['leisure_suit', 'larry_magna', 'cum_laude', 'uncut']
# 1036:['leisure_suit', 'larry_magna', 'cum_laude']
# 1036:['leisure_suit', 'larry_magna', 'cum_laude']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '54']
# Would be reclassified into: 524
# With accuracy: 0.0012989189155681446
# Items in this cluster are:
# 524:['3sega', 'bass_fishing', 'duel', '54', '812_k']
# ----------------------------------
#
# Originals as noise, names:
# ['bust', 'bloc']
# Would be reclassified into: 1333
# With accuracy: 0.0014216657647251423
# Items in this cluster are:
# 1333:['super', 'bust', 'move']
# ----------------------------------
#
# Originals as noise, names:
# ['strike', 'force', 'bowling']
# Would be reclassified into: 617
# With accuracy: 0.002813051884957945
# Items in this cluster are:
# 617:['strike_force', 'bowling', '31', '974', 'k', 'keilaus']
# ----------------------------------
#
# Originals as noise, names:
# ['astro', 'boy']
# ['demolition', 'girl', 'playstation', '2']
# Would be reclassified into: 1059
# With accuracy: 0.0012989216419338832
# Items in this cluster are:
# 1059:['singstar', 'boy', 'bands', 'vs', 'girl', 'bands']
# ----------------------------------
#
# Originals as noise, names:
# ['kultainen', 'kompassi']
# ['kultainen', 'kompassi']
# Would be reclassified into: 331
# With accuracy: 0.0014162713174661445
# Items in this cluster are:
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass', 'kultainen_kompassi', 'pal']
# 331:['golden_compass']
# ----------------------------------
#
# Originals as noise, names:
# ['spyro', '–', 'dawn', 'dragon']
# Would be reclassified into: 1217
# With accuracy: 0.0038664379543693022
# Items in this cluster are:
# 1217:['legend_spyro', 'dawn_dragon']
# 1217:['legend_spyro', 'dawn_dragon']
# ----------------------------------
#
# Originals as noise, names:
# ['kultainen', 'kompassi']
# ['kultainen', 'kompassi']
# Would be reclassified into: 331
# With accuracy: 0.0014162713174661445
# Items in this cluster are:
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass']
# 331:['golden_compass', 'kultainen_kompassi', 'pal']
# 331:['golden_compass']
# ----------------------------------
#
# Originals as noise, names:
# ['dancing', 'stage', 'max']
# Would be reclassified into: 402
# With accuracy: 0.009110395367366667
# Items in this cluster are:
# 402:['dancing_stage', 'fusion']
# 402:['dancing_stage', 'fusion']
# 402:['dancing_stage', 'fusion']
# 402:['dancing_stage', 'fusion']
# ----------------------------------
#
# Originals as noise, names:
# ['spy', 'hunter', '7462']
# Would be reclassified into: 663
# With accuracy: 0.007252629242894306
# Items in this cluster are:
# 663:['spy_hunter', 'nowhere_run']
# 663:['spy_hunter', 'nowhere_run']
# 663:['spy_hunter', 'nowhere_run']
# ----------------------------------
#
# Originals as noise, names:
# ['fast', 'and', 'furious']
# Would be reclassified into: 421
# With accuracy: 0.003160164568834006
# Items in this cluster are:
# 421:['playstation_2', 'autopelit', 'midnight_club', '3_ja', 'fast_and', 'furious']
# ----------------------------------
#
# Originals as noise, names:
# ['madden', '2004']
# ['fifa', '2004']
# Would be reclassified into: 245
# With accuracy: 0.010083245855667894
# Items in this cluster are:
# 245:['fifa_football', '2004', '11333']
# 245:['fifa_football', '2004', 'playstation_2']
# 245:['fifa_football', '2004']
# 245:['fifa_football', '2004']
# 245:['fifa_football', '2004', '27']
# ----------------------------------
#
# Originals as noise, names:
# ['astro', 'boy']
# ['demolition', 'girl', 'playstation', '2']
# Would be reclassified into: 1059
# With accuracy: 0.0012989216419338832
# Items in this cluster are:
# 1059:['singstar', 'boy', 'bands', 'vs', 'girl', 'bands']
# ----------------------------------
#
# Originals as noise, names:
# ['captain', 'scarlett']
# Would be reclassified into: 1129
# With accuracy: 0.0013616149235995468
# Items in this cluster are:
# 1129:['captain_scarlett', 'pk', '2', '00€']
# ----------------------------------
#
# Originals as noise, names:
# ['dog', 'island']
# ['paavo', 'pesusieni']
# Would be reclassified into: 148
# With accuracy: 0.004173510169827388
# Items in this cluster are:
# 148:['paavo_pesusieni', 'battle_volcano', 'island']
# 148:['paavo_pesusieni', 'battle_volcano', 'island']
# 148:['paavo_pesusieni', 'battle_volcano', 'island']
# ----------------------------------
#
# Originals as noise, names:
# ['juiced', '2', '446']
# Would be reclassified into: 67
# With accuracy: 0.007027239017674773
# Items in this cluster are:
# 67:['juiced_2', 'hot_import', 'nights']
# 67:['juiced_2', 'hot_import', 'nights']
# 67:['juiced_2', 'hot_import', 'nights']
# 67:['ps_2', 'juiced_2', 'hot_import', 'nights', 'pal']
# 67:['–', 'juiced_2', 'hot_import', 'nights']
# 67:['juiced_2', 'hot_import', 'nights']
# 67:['juiced_2', 'hot_import', 'nights']
# 67:['juiced_2', 'hot_import', 'nights']
# ----------------------------------
#
# Originals as noise, names:
# ['king', 'arthur']
# Would be reclassified into: 798
# With accuracy: 0.0013720598487197131
# Items in this cluster are:
# 798:['king_arthur', 'truth', 'behind', 'legend']
# ----------------------------------
#
# Originals as noise, names:
# ['speed', 'challenge']
# Would be reclassified into: 1225
# With accuracy: 0.0013722053399859307
# Items in this cluster are:
# 1225:['speed_challenge', 'jacques_villeneuve', 's', 'racing_vision']
# ----------------------------------
#
# Originals as noise, names:
# ['hardware', 'online', 'arena']
# Would be reclassified into: 280
# With accuracy: 0.0021813129079852164
# Items in this cluster are:
# 280:['hardware_online', 'arena', '42', '490', 'k', 'network', 'play', 'only']
# ----------------------------------
#
# Originals as noise, names:
# ['nhl', '2k8', 'playstation', '2']
# Would be reclassified into: 1470
# With accuracy: 0.0014427172373663519
# Items in this cluster are:
# 1470:['nhl_2k8', '482']
# ----------------------------------
#
# Originals as noise, names:
# ['madden', '2004']
# ['fifa', '2004']
# Would be reclassified into: 245
# With accuracy: 0.010073181833505874
# Items in this cluster are:
# 245:['fifa_football', '2004', '11333']
# 245:['fifa_football', '2004', 'playstation_2']
# 245:['fifa_football', '2004']
# 245:['fifa_football', '2004']
# 245:['fifa_football', '2004', '27']
# ----------------------------------
#
# Originals as noise, names:
# ['celtic', 'club', 'football']
# Would be reclassified into: 500
# With accuracy: 0.0037037768216301734
# Items in this cluster are:
# 500:['real_madrir', 'club_football']
# 500:['real_madrir', 'club_football']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '22']
# Would be reclassified into: 582
# With accuracy: 0.0014167004552043856
# Items in this cluster are:
# 582:['lma_manager', '2005']
# 582:['lma_manager', '2005', '22']
# ----------------------------------
#
# Originals as noise, names:
# ['riding', 'star', '209']
# Would be reclassified into: 930
# With accuracy: 0.0013711998724436133
# Items in this cluster are:
# 930:['tim', 'stockdale', 's', 'riding_star']
# ----------------------------------
#
# Originals as noise, names:
# ['knockout', 'kings', '2002']
# ['cricket', '2002']
# ['madden', 'nfl', '2002']
# Would be reclassified into: 495
# With accuracy: 0.006000069413999881
# Items in this cluster are:
# 495:['is_football', '2002', 'platinum']
# 495:['is_football', '2002']
# 495:['is_football', '2002']
# ----------------------------------
#
# Originals as noise, names:
# ['gt', 'r', '400']
# Would be reclassified into: 703
# With accuracy: 0.002827990067732964
# Items in this cluster are:
# 703:['grand', 'tour', 'racing', 'gt_r', '400', '262']
# ----------------------------------
#
# Originals as noise, names:
# ['smash', 'cars']
# Would be reclassified into: 1104
# With accuracy: 0.0013710749728779506
# Items in this cluster are:
# 1104:['shrek', 'smash', 'n', 'crash_racing']
# ----------------------------------
#
# Originals as noise, names:
# ['nba', '08']
# ['ps', '2', 'nba', 'live', '2005', 'b', 'pal']
# Would be reclassified into: 394
# With accuracy: 0.011452110712878744
# Items in this cluster are:
# 394:['nba_live', '08']
# 394:['nba_live', '08']
# 394:['nba_live', '08']
# 394:['nba_live', '08']
# 394:['nba_live', '08']
# ----------------------------------
#
# Originals as noise, names:
# ['ex', 'zeus', 'pal', 'sinetöity']
# Would be reclassified into: 939
# With accuracy: 0.003864380819410555
# Items in this cluster are:
# 939:['lake_masters', 'ex']
# 939:['lake_masters', 'ex']
# ----------------------------------
#
# Originals as noise, names:
# ['incredible', 'hulk', '10599']
# Would be reclassified into: 1280
# With accuracy: 0.0014210142829184675
# Items in this cluster are:
# 1280:['incredible_hulk', 'official', 'videogame']
# ----------------------------------
#
# Originals as noise, names:
# ['impossible', 'mission']
# ['mega', 'man', 'x8']
# Would be reclassified into: 1314
# With accuracy: 0.0014221685039407465
# Items in this cluster are:
# 1314:['mega_man', 'x_command', 'mission']
# ----------------------------------
#
# Originals as noise, names:
# ['red', 'ninja']
# Would be reclassified into: 727
# With accuracy: 0.001302939020990455
# Items in this cluster are:
# 727:['red_ninja', 'end', 'honour', 'promo_pelin', 'täysversio']
# ----------------------------------
#
# Originals as noise, names:
# ['singsta', 'pop', 'hits']
# Would be reclassified into: 236
# With accuracy: 0.014162047578813834
# Items in this cluster are:
# 236:['dance_party', 'pop_hits']
# 236:['dance_party', 'pop_hits']
# 236:['dance_party', 'pop_hits']
# 236:['dance_party', 'pop_hits']
# 236:['dance_party', 'pop_hits']
# 236:['dance_party', 'pop_hits']
# ----------------------------------
#
# Originals as noise, names:
# ['impossible', 'mission']
# ['mega', 'man', 'x8']
# Would be reclassified into: 1314
# With accuracy: 0.001418276566266065
# Items in this cluster are:
# 1314:['mega_man', 'x_command', 'mission']
# ----------------------------------
#
# Originals as noise, names:
# ['evil', 'may', 'cry']
# Would be reclassified into: 395
# With accuracy: 0.0019076794334011403
# Items in this cluster are:
# 395:['resident_evil', 'code_veronica', 'x_devil', 'may_cry', 'demo']
# 395:['resident_evil', '–', 'code_veronica', 'x_devil', 'may_cry', 'demo']
# ----------------------------------
#
# Originals as noise, names:
# ['kidz', 'sports', 'basketball']
# Would be reclassified into: 766
# With accuracy: 0.0013726234940774696
# Items in this cluster are:
# 766:['kidz_sports', 'ice', 'hockey', '10901']
# ----------------------------------
#
# Originals as noise, names:
# ['spytoy']
# Would be reclassified into: 1011
# With accuracy: 0.001421283372191978
# Items in this cluster are:
# 1011:['eyetoy', 'spytoy', '9771']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'motogp', 'pal']
# Would be reclassified into: 1508
# With accuracy: 0.0014405379420707218
# Items in this cluster are:
# 1508:['motogp', '07']
# ----------------------------------
#
# Originals as noise, names:
# ['csi', 'dimensions', 'murder']
# Would be reclassified into: 940
# With accuracy: 0.003864380819410555
# Items in this cluster are:
# 940:['csi_3', 'dimensions_murder']
# 940:['csi_3', 'dimensions_murder']
# ----------------------------------
#
# Originals as noise, names:
# ['f1', '06']
# Would be reclassified into: 806
# With accuracy: 0.0012989123147877258
# Items in this cluster are:
# 806:['f1_06', 'formula', '1', '2006', '490']
# ----------------------------------
#
# Originals as noise, names:
# ['007', 'quantum', 'solace']
# Would be reclassified into: 324
# With accuracy: 0.011368628116078746
# Items in this cluster are:
# 324:['james_bond', 'quantum_solace']
# 324:['james_bond', 'quantum_solace']
# 324:['james_bond', 'quantum_solace']
# 324:['james_bond', 'quantum_solace']
# ----------------------------------
#
# Originals as noise, names:
# ['caspers', 'scare', 'school', 'pal', 'sinetöity']
# Would be reclassified into: 952
# With accuracy: 0.0036448096930750957
# Items in this cluster are:
# 952:['casper', 'scare_school']
# 952:['casper', 's', 'scare_school']
# ----------------------------------
#
# Originals as noise, names:
# ['psi', 'ops']
# Would be reclassified into: 1586
# With accuracy: 0.001433918600109343
# Items in this cluster are:
# 1586:['psi_ops', 'mindgate_conspiracy']
# ----------------------------------
#
# Originals as noise, names:
# ['eyetoy', 'kamera']
# ['eyetoy', 'chat']
# Would be reclassified into: 300
# With accuracy: 0.001636323269982022
# Items in this cluster are:
# 300:['sega_superstars', 'ps_ii']
# 300:['sega_superstars', 'eyetoy']
# 300:['sega_superstars']
# 300:['ps_2', 'sega_superstars', 'pal']
# 300:['sega_superstars']
# ----------------------------------
#
# Originals as noise, names:
# ['hitman', '2']
# Would be reclassified into: 84
# With accuracy: 0.021316505213856366
# Items in this cluster are:
# 84:['hitman_2', 'silent_assassin']
# 84:['hitman_2', 'silent_assassin']
# 84:['hitman_2', 'silent_assassin']
# 84:['hitman_2', 'silent_assassin']
# 84:['hitman_2', 'silent_assassin']
# 84:['hitman_2', 'silent_assassin']
# 84:['hitman_2', 'silent_assassin']
# 84:['hitman_2', 'silent_assassin']
# 84:['ps_2', 'hitman_2', 'silent_assassin', 'pal']
# 84:['hitman_2', 'silent_assassin']
# ----------------------------------
#
# Originals as noise, names:
# ['urban', 'reign']
# Would be reclassified into: 1191
# With accuracy: 0.0013729004381998907
# Items in this cluster are:
# 1191:['urban', 'chaos', 'riot', 'response']
# ----------------------------------
#
# Originals as noise, names:
# ['sonic', 'unleashed', '12217']
# Would be reclassified into: 975
# With accuracy: 0.0013731048867557801
# Items in this cluster are:
# 975:['sonic_unleashed', '26', '202', 'tasohyppely']
# ----------------------------------
#
# Originals as noise, names:
# ['formula', 'challenge']
# ['lotus', 'challenge']
# Would be reclassified into: 210
# With accuracy: 0.013053095897353612
# Items in this cluster are:
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['ps_2', 'grand_prix', 'challenge', 'b_pal']
# ----------------------------------
#
# Originals as noise, names:
# ['twenty', 'party', 'playstation', '2']
# ['play', 'station', '2', 'pelilevy', 'nro', '39']
# Would be reclassified into: 154
# With accuracy: 0.001043324306251911
# Items in this cluster are:
# 154:['twenty_2', 'party']
# 154:['twenty_2', 'party']
# 154:['twenty_2', 'party']
# 154:['twenty_2', 'party', '39']
# 154:['twenty_2', 'party']
# 154:['ps_2', 'twenty_2', 'party', 'pal']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '19']
# Would be reclassified into: 1262
# With accuracy: 0.0013007721552907837
# Items in this cluster are:
# 1262:['ferrari_challenge', 'trofeo_pirelli', '19', '673', 'k']
# ----------------------------------
#
# Originals as noise, names:
# ['eye', 'toy', 'chat']
# ['spytoy', 'eye', 'toy']
# ['eye', 'toy', 'play']
# ['play', 'sports']
# ['eye', 'toy', 'astro', 'zoo']
# Would be reclassified into: 406
# With accuracy: 0.011305634224073666
# Items in this cluster are:
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# ----------------------------------
#
# Originals as noise, names:
# ['football', 'generation']
# Would be reclassified into: 318
# With accuracy: 0.012474873287252634
# Items in this cluster are:
# 318:['england_international', 'football']
# 318:['england_international', 'football']
# 318:['england_international', 'football']
# 318:['england_international', 'football']
# 318:['england_international', 'football']
# ----------------------------------
#
# Originals as noise, names:
# ['puzzle', 'quest']
# Would be reclassified into: 159
# With accuracy: 0.006215678832044447
# Items in this cluster are:
# 159:['lord_rings', 'aragorn_s', 'quest']
# 159:['lord_rings', 'aragorn_s', 'quest']
# 159:['lord_rings', 'aragorn_s', 'quest']
# 159:['lord_rings', 'aragorn_s', 'quest']
# 159:['lord_rings', 'aragorn_s', 'quest']
# 159:['lord_rings', 'aragorn_s', 'quest', 'ps_ii']
# 159:['lord_rings', 'aragorn_s', 'quest']
# 159:['lord_rings', 'aragorn_s', 'quest']
# 159:['lord_rings', 'aragorn_s', 'quest']
# ----------------------------------
#
# Originals as noise, names:
# ['nemoa', 'etsimässä']
# Would be reclassified into: 795
# With accuracy: 0.003864380819410555
# Items in this cluster are:
# 795:['nemoa_etsimässä', 'finding_nemo']
# 795:['nemoa_etsimässä', 'finding_nemo']
# ----------------------------------
#
# Originals as noise, names:
# ['eyetoy', 'kamera']
# ['eyetoy', 'chat']
# Would be reclassified into: 300
# With accuracy: 0.001636323269982022
# Items in this cluster are:
# 300:['sega_superstars', 'ps_ii']
# 300:['sega_superstars', 'eyetoy']
# 300:['sega_superstars']
# 300:['ps_2', 'sega_superstars', 'pal']
# 300:['sega_superstars']
# ----------------------------------
#
# Originals as noise, names:
# ['shadow', 'zorro']
# Would be reclassified into: 573
# With accuracy: 0.0013702003092022946
# Items in this cluster are:
# 573:['shadow_zorro', '20', '017', 'k']
# ----------------------------------
#
# Originals as noise, names:
# ['dark', 'summit']
# Would be reclassified into: 1423
# With accuracy: 0.0014098964933404495
# Items in this cluster are:
# 1423:['kya', 'dark', 'lineage']
# ----------------------------------
#
# Originals as noise, names:
# ['kessen', '2']
# Would be reclassified into: 48
# With accuracy: 0.0015991818621869781
# Items in this cluster are:
# 48:['london_racer', 'ii']
# 48:['kingdom_hearts', 'ii']
# 48:['kingdom_hearts', 'ii', '2', 'pal']
# 48:['kingdom_hearts', 'ii']
# 48:['pacific_warriors', 'ii']
# 48:['kingdom_hearts', 'ii']
# 48:['kessen_2', 'ii']
# 48:['kingdom_hearts', 'ii']
# 48:['kingdom_hearts', 'ii']
# 48:['kingdom_hearts', 'ii']
# 48:['blade', 'ii']
# 48:['kingdom_hearts', 'ii', '2', '492']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '60']
# Would be reclassified into: 990
# With accuracy: 0.0014190759495326414
# Items in this cluster are:
# 990:['next_generation', 'tennis', '60']
# 990:['next_generation', 'tennis', '2003']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '16']
# Would be reclassified into: 1067
# With accuracy: 0.0012225291831448714
# Items in this cluster are:
# 1067:['pro_evolution', 'soccer_2008', '16', '493', 'k', 'pes_2008']
# ----------------------------------
#
# Originals as noise, names:
# ['nascar', '09', 'playstation', '2']
# Would be reclassified into: 599
# With accuracy: 0.006914533242769021
# Items in this cluster are:
# 599:['tiger_woods', 'pga_tour', '09']
# 599:['tiger_woods', 'pga_tour', '09']
# 599:['tiger_woods', 'pga_tour', '09']
# 599:['tiger_woods', 'pga_tour', '09']
# ----------------------------------
#
# Originals as noise, names:
# ['death', 'degrees']
# Would be reclassified into: 351
# With accuracy: 0.0015246429840483841
# Items in this cluster are:
# 351:['judge_dredd']
# 351:['judge_dredd', 'dredd_vs', 'death']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'gta', '3', 'pal']
# ['ps', '2', 'reel', 'fishing', '3', 'pal']
# Would be reclassified into: 95
# With accuracy: 0.0015785583951406672
# Items in this cluster are:
# 95:['eyetoy_play', 'hero']
# 95:['ps_2', 'eyetoy_play', '3_pal']
# 95:['eyetoy_play']
# 95:['eyetoy_play']
# 95:['eyetoy_play', 'platinum', 'vain_levy']
# 95:['eyetoy_play']
# 95:['ps_2', 'eyetoy_play', 'pal']
# 95:['eyetoy_play']
# 95:['eyetoy_play']
# ----------------------------------
#
# Originals as noise, names:
# ['silent', 'scope']
# ['silent', 'scope']
# Would be reclassified into: 587
# With accuracy: 0.0013627491103864176
# Items in this cluster are:
# 587:['silent_scope', '2', 'fatal', 'judgement']
# ----------------------------------
#
# Originals as noise, names:
# ['area', '51']
# Would be reclassified into: 1631
# With accuracy: 0.0014399604223452572
# Items in this cluster are:
# 1631:['area_51', 'promo']
# ----------------------------------
#
# Originals as noise, names:
# ['soldier', 'fortune', '464']
# Would be reclassified into: 851
# With accuracy: 0.003864380819410555
# Items in this cluster are:
# 851:['soldier_fortune', 'gold_edition']
# 851:['soldier_fortune', 'gold_edition']
# ----------------------------------
#
# Originals as noise, names:
# ['fighting', 'fury']
# ['fighting', 'angelsps2']
# Would be reclassified into: 1551
# With accuracy: 0.0014180187668310004
# Items in this cluster are:
# 1551:['pride', 'fighting', 'championships']
# ----------------------------------
#
# Originals as noise, names:
# ['eye', 'toy', 'chat']
# ['spytoy', 'eye', 'toy']
# ['eye', 'toy', 'play']
# ['play', 'sports']
# ['eye', 'toy', 'astro', 'zoo']
# Would be reclassified into: 406
# With accuracy: 0.011080972728402893
# Items in this cluster are:
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# ----------------------------------
#
# Originals as noise, names:
# ['darkwatch', 'promo']
# Would be reclassified into: 490
# With accuracy: 0.0026906082023544524
# Items in this cluster are:
# 490:['marvel_vs', 'capcom_2', 'promo']
# 490:['marvel_vs', 'capcom_2', 'promo']
# ----------------------------------
#
# Originals as noise, names:
# ['dj', 'vendetta']
# Would be reclassified into: 113
# With accuracy: 0.007248577042736591
# Items in this cluster are:
# 113:['die_hard', 'vendetta']
# 113:['die_hard', 'vendetta']
# 113:['die_hard', 'vendetta']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'rhytmic', 'star', 'pal']
# Would be reclassified into: 1195
# With accuracy: 0.0014173167193523596
# Items in this cluster are:
# 1195:['pop', 'star', 'academy', 'muoveissa']
# ----------------------------------
#
# Originals as noise, names:
# ['age', 'empires', 'age', 'kings']
# Would be reclassified into: 518
# With accuracy: 0.002808675695256231
# Items in this cluster are:
# 518:['age_empires', 'ii_age', 'kings']
# 518:['age_empires', 'ii_age', 'kings', '470']
# ----------------------------------
#
# Originals as noise, names:
# ['metropolismania', 'ps', 'ii']
# ['ps', '2', 'pes', 'management', 'pal']
# ['vegas', 'casino']
# Would be reclassified into: 5
# With accuracy: 0.0017310655818382887
# Items in this cluster are:
# 5:['soulcalibur', '2']
# 5:['pes', '2']
# 5:['warriors_orochi', '2']
# 5:['castle_shikigami', '2']
# 5:['time_crisis', '2']
# 5:['vegas_casino', '2']
# 5:['ice_age', '2']
# 5:['midnight_club', '2']
# 5:['metropolismania', '2']
# 5:['warriors_orochi', '2']
# ----------------------------------
#
# Originals as noise, names:
# ['eye', 'toy', 'chat']
# ['spytoy', 'eye', 'toy']
# ['eye', 'toy', 'play']
# ['play', 'sports']
# ['eye', 'toy', 'astro', 'zoo']
# Would be reclassified into: 406
# With accuracy: 0.01720023514008179
# Items in this cluster are:
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# ----------------------------------
#
# Originals as noise, names:
# ['top', 'gun', 'ps', '2']
# Would be reclassified into: 781
# With accuracy: 0.003864380819410555
# Items in this cluster are:
# 781:['top_gun', 'combat_zones']
# 781:['top_gun', 'combat_zones']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '44']
# Would be reclassified into: 749
# With accuracy: 0.0011373723613739405
# Items in this cluster are:
# 749:['ghost_hunter', '44', '290', 'k', '2003', 'aave', 'metsästys']
# ----------------------------------
#
# Originals as noise, names:
# ['cronicles', 'narnia', 'ps', '2']
# Would be reclassified into: 679
# With accuracy: 0.003011923244109245
# Items in this cluster are:
# 679:['cronicles_narnia', 'lion_wich', 'and_w']
# 679:['cronicles_narnia', 'lion_wich', 'and_w']
# ----------------------------------
#
# Originals as noise, names:
# ['new', 'york', 'race']
# Would be reclassified into: 163
# With accuracy: 0.00788984996455631
# Items in this cluster are:
# 163:['true_crime', 'new_york', 'city']
# 163:['true_crime', 'new_york', 'city']
# 163:['true_crime', 'new_york', 'city', '12290']
# 163:['true_crime', 'new_york', 'city']
# 163:['true_crime', 'new_york', 'city', '347']
# 163:['true_crime', 'new_york', 'city', 'pal']
# 163:['ps_2', 'true_crime', 'new_york', 'city', 'pal']
# 163:['true_crime', 'new_york', 'city', 'ps_2']
# 163:['true_crime', 'new_york', 'city']
# 163:['true_crime', 'new_york', 'city']
# ----------------------------------
#
# Originals as noise, names:
# ['eyetoy', 'kinetic']
# ['eyetoy', 'kinetic']
# Would be reclassified into: 516
# With accuracy: 0.003830622764531529
# Items in this cluster are:
# 516:['ps_2', 'eyetoy_kinetic', 'combat', 'b_pal']
# 516:['eyetoy_kinetic', 'combat']
# ----------------------------------
#
# Originals as noise, names:
# ['go', 'go', 'golf']
# ['grazy', 'golf']
# ['leaderboard', 'golf']
# Would be reclassified into: 1544
# With accuracy: 0.001429670037755144
# Items in this cluster are:
# 1544:['mr', 'golf']
# ----------------------------------
#
# Originals as noise, names:
# ['indycar', 'series']
# Would be reclassified into: 754
# With accuracy: 0.0013000154153189375
# Items in this cluster are:
# 754:['indycar_series', '2005', '42', '431', 'k']
# ----------------------------------
#
# Originals as noise, names:
# ['trivial', 'pursuit']
# ['trivial', 'pursuit']
# Would be reclassified into: 1231
# With accuracy: 0.0014223935159845675
# Items in this cluster are:
# 1231:['trivial_pursuit', 'haluatko', 'miljonääriksi']
# ----------------------------------
#
# Originals as noise, names:
# ['silent', 'scope']
# ['silent', 'scope']
# Would be reclassified into: 587
# With accuracy: 0.0013627491103864176
# Items in this cluster are:
# 587:['silent_scope', '2', 'fatal', 'judgement']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'nba', '2k11', 'pal']
# Would be reclassified into: 1304
# With accuracy: 0.0014421293418012229
# Items in this cluster are:
# 1304:['nba', '2k10']
# ----------------------------------
#
# Originals as noise, names:
# ['onimusha', '2']
# Would be reclassified into: 945
# With accuracy: 0.0013708665601290808
# Items in this cluster are:
# 945:['onimusha_2', 'samurai', 's', 'destiny']
# ----------------------------------
#
# Originals as noise, names:
# ['sled', 'storm']
# Would be reclassified into: 128
# With accuracy: 0.018896812776553154
# Items in this cluster are:
# 128:['conflict_global', 'storm', '9554']
# 128:['conflict_global', 'storm']
# 128:['conflict_global', 'storm', 'promo']
# 128:['conflict_global', 'storm']
# 128:['conflict_global', 'storm']
# 128:['conflict_global', 'storm']
# 128:['conflict_global', 'storm']
# 128:['conflict_global', 'storm']
# 128:['conflict_global', 'storm']
# 128:['conflict_global', 'storm']
# ----------------------------------
#
# Originals as noise, names:
# ['phantom', 'brave']
# Would be reclassified into: 1561
# With accuracy: 0.0014462463111503934
# Items in this cluster are:
# 1561:['phantom_brave', 'japan']
# ----------------------------------
#
# Originals as noise, names:
# ['dog', 'island']
# ['paavo', 'pesusieni']
# Would be reclassified into: 148
# With accuracy: 0.004134983591179819
# Items in this cluster are:
# 148:['paavo_pesusieni', 'battle_volcano', 'island']
# 148:['paavo_pesusieni', 'battle_volcano', 'island']
# 148:['paavo_pesusieni', 'battle_volcano', 'island']
# ----------------------------------
#
# Originals as noise, names:
# ['grandia', 'ii']
# ['grandia', 'ii']
# Would be reclassified into: 1106
# With accuracy: 0.0014123548562460773
# Items in this cluster are:
# 1106:['grandia_ii', '2', 'pal']
# ----------------------------------
#
# Originals as noise, names:
# ['eyetoy', 'kinetic']
# ['eyetoy', 'kinetic']
# Would be reclassified into: 516
# With accuracy: 0.003830622764531529
# Items in this cluster are:
# 516:['ps_2', 'eyetoy_kinetic', 'combat', 'b_pal']
# 516:['eyetoy_kinetic', 'combat']
# ----------------------------------
#
# Originals as noise, names:
# ['eye', 'toy', 'chat']
# ['spytoy', 'eye', 'toy']
# ['eye', 'toy', 'play']
# ['play', 'sports']
# ['eye', 'toy', 'astro', 'zoo']
# Would be reclassified into: 406
# With accuracy: 0.011247684223820264
# Items in this cluster are:
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# 406:['eye_toy', 'play_sports']
# ----------------------------------
#
# Originals as noise, names:
# ['metropolismania', 'ps', 'ii']
# ['ps', '2', 'pes', 'management', 'pal']
# ['vegas', 'casino']
# Would be reclassified into: 5
# With accuracy: 0.0017122978157070661
# Items in this cluster are:
# 5:['soulcalibur', '2']
# 5:['pes', '2']
# 5:['warriors_orochi', '2']
# 5:['castle_shikigami', '2']
# 5:['time_crisis', '2']
# 5:['vegas_casino', '2']
# 5:['ice_age', '2']
# 5:['midnight_club', '2']
# 5:['metropolismania', '2']
# 5:['warriors_orochi', '2']
# ----------------------------------
#
# Originals as noise, names:
# ['mortal', 'kombat', 'armageddon']
# Would be reclassified into: 389
# With accuracy: 0.008913360683726586
# Items in this cluster are:
# 389:['mortal_kombat', 'shaolin_monks']
# 389:['mortal_kombat', 'shaolin_monks', 'playstation_2', 'ntsc']
# 389:['mortal_kombat', 'shaolin_monks']
# 389:['mortal_kombat', 'shaolin_monks']
# ----------------------------------
#
# Originals as noise, names:
# ['burnout', '3']
# Would be reclassified into: 226
# With accuracy: 0.014900485288516757
# Items in this cluster are:
# 226:['burnout_3', 'takedown']
# 226:['burnout_3', 'takedown']
# 226:['burnout_3', 'takedown']
# 226:['burnout_3', 'takedown']
# 226:['ps_2', 'burnout_3', 'takedown', 'pal']
# 226:['burnout_3', 'takedown']
# ----------------------------------
#
# Originals as noise, names:
# ['go', 'go', 'golf']
# ['grazy', 'golf']
# ['leaderboard', 'golf']
# Would be reclassified into: 1544
# With accuracy: 0.001430140927054757
# Items in this cluster are:
# 1544:['mr', 'golf']
# ----------------------------------
#
# Originals as noise, names:
# ['hidden', 'invasion']
# Would be reclassified into: 762
# With accuracy: 0.0013716826533084234
# Items in this cluster are:
# 762:['extreme', 'ghostbusters', '–', 'ultimate', 'invasion']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'gta', '3', 'pal']
# ['ps', '2', 'reel', 'fishing', '3', 'pal']
# Would be reclassified into: 95
# With accuracy: 0.0015785583951406672
# Items in this cluster are:
# 95:['eyetoy_play', 'hero']
# 95:['ps_2', 'eyetoy_play', '3_pal']
# 95:['eyetoy_play']
# 95:['eyetoy_play']
# 95:['eyetoy_play', 'platinum', 'vain_levy']
# 95:['eyetoy_play']
# 95:['ps_2', 'eyetoy_play', 'pal']
# 95:['eyetoy_play']
# 95:['eyetoy_play']
# ----------------------------------
#
# Originals as noise, names:
# ['ratched', 'clank', '3']
# Would be reclassified into: 1210
# With accuracy: 0.0014195001961333368
# Items in this cluster are:
# 1210:['ratchet', 'and', 'clank_3']
# ----------------------------------
#
# Originals as noise, names:
# ['knockout', 'kings', '2002']
# ['cricket', '2002']
# ['madden', 'nfl', '2002']
# Would be reclassified into: 495
# With accuracy: 0.006012613660740898
# Items in this cluster are:
# 495:['is_football', '2002', 'platinum']
# 495:['is_football', '2002']
# 495:['is_football', '2002']
# ----------------------------------
#
# Originals as noise, names:
# ['oni']
# ['oni']
# Would be reclassified into: 1042
# With accuracy: 0.001298471946383192
# Items in this cluster are:
# 1042:['oni', 'dark', 'future', 'uncertain', 'past']
# ----------------------------------
#
# Originals as noise, names:
# ['resident', 'evil', '4', 'suomiversio']
# Would be reclassified into: 75
# With accuracy: 0.018927570905219827
# Items in this cluster are:
# 75:['resident_evil', '4']
# 75:['resident_evil', '4']
# 75:['resident_evil', '4']
# 75:['resident_evil', '4']
# 75:['resident_evil', '4', '331']
# 75:['resident_evil', '4']
# 75:['resident_evil', '4', 'platinum']
# 75:['loistokuntoinen', 'resident_evil', '4']
# ----------------------------------
#
# Originals as noise, names:
# ['crisis', 'zone']
# Would be reclassified into: 1519
# With accuracy: 0.0014216911587205405
# Items in this cluster are:
# 1519:['seed', 'war', 'zone', 'pal_sinetöity']
# ----------------------------------
#
# Originals as noise, names:
# ['off', 'road']
# ['off', 'road']
# Would be reclassified into: 1052
# With accuracy: 0.0014464756356557871
# Items in this cluster are:
# 1052:['ford', 'off_road']
# ----------------------------------
#
# Originals as noise, names:
# ['reel', 'fishing', 'iii']
# Would be reclassified into: 85
# With accuracy: 0.016807267557443092
# Items in this cluster are:
# 85:['speed_machines', 'iii']
# 85:['speed_machines', 'iii']
# 85:['speed_machines', 'iii']
# 85:['speed_machines', 'iii']
# 85:['speed_machines', 'iii', '8208']
# 85:['speed_machines', 'iii']
# 85:['o', 'speed_machines', 'iii']
# 85:['speed_machines', 'iii']
# ----------------------------------
#
# Originals as noise, names:
# ['disgaea', '2']
# Would be reclassified into: 918
# With accuracy: 0.003864380819410555
# Items in this cluster are:
# 918:['disgaea_2', 'cursed_memories']
# 918:['disgaea_2', 'cursed_memories', 'pal']
# ----------------------------------
#
# Originals as noise, names:
# ['grandia', 'ii']
# ['grandia', 'ii']
# Would be reclassified into: 1106
# With accuracy: 0.0014123548562460773
# Items in this cluster are:
# 1106:['grandia_ii', '2', 'pal']
# ----------------------------------
#
# Originals as noise, names:
# ['play', 'station', '2', 'pelilevy', 'nro', '18']
# Would be reclassified into: 723
# With accuracy: 0.001285122322592737
# Items in this cluster are:
# 723:['18', 'wheeler', 'american', 'pro', 'trucker']
# ----------------------------------
#
# Originals as noise, names:
# ['despicable', 'me']
# Would be reclassified into: 894
# With accuracy: 0.0013625724273756835
# Items in this cluster are:
# 894:['ps_2', 'my', 'horse', 'me', '2', 'b_pal']
# ----------------------------------
#
# Originals as noise, names:
# ['hugo', 'pelit', '5', 'kpl', 'ps', '2']
# Would be reclassified into: 1341
# With accuracy: 0.0014051676294311495
# Items in this cluster are:
# 1341:['need_speed', 'playstation_2', 'pelipaketti', '5_kpl', 'pelejä']
# ----------------------------------
#
# Originals as noise, names:
# ['fahrenheit']
# Would be reclassified into: 662
# With accuracy: 0.0016266107038710948
# Items in this cluster are:
# 662:['playstation_magazine', 'demo', '12']
# 662:['playstation_2', 'demo', 'disc']
# 662:['fahrenheit', 'demo']
# 662:['athens', 'demo']
# 662:['ps_2', 'demo']
# 662:['ps_2', 'demo']
# ----------------------------------
#
# Originals as noise, names:
# ['crazyfrog', 'racer', '2']
# Would be reclassified into: 230
# With accuracy: 0.015292006354768031
# Items in this cluster are:
# 230:['crazy_frog', 'racer_2']
# 230:['crazy_frog', 'racer_2']
# 230:['crazy_frog', 'racer_2']
# 230:['crazy_frog', 'racer_2']
# 230:['crazy_frog', 'racer_2']
# 230:['crazy_frog', 'racer_2']
# ----------------------------------
#
# Originals as noise, names:
# ['persona', '3', 'pal', 'sealed']
# Would be reclassified into: 1236
# With accuracy: 0.0016631242466955652
# Items in this cluster are:
# 1236:['odin_sphere']
# 1236:['odin_sphere']
# 1236:['odin_sphere', 'pal_sealed']
# ----------------------------------
#
# Originals as noise, names:
# ['aeon', 'flux']
# Would be reclassified into: 1149
# With accuracy: 0.0013691238031692358
# Items in this cluster are:
# 1149:['rocky', 'aeon_flux', 'catwoman', 'lord_rings']
# ----------------------------------
#
# Originals as noise, names:
# ['pinball']
# ['powershot', 'pinball']
# Would be reclassified into: 589
# With accuracy: 0.007179912597707362
# Items in this cluster are:
# 589:['play_it', 'pinball']
# 589:['play_it', 'pinball']
# 589:['play_it', 'pinball']
# ----------------------------------
#
# Originals as noise, names:
# ['makai', 'kingdom']
# ['makai', 'kingdom']
# Would be reclassified into: 830
# With accuracy: 0.0013723989956249034
# Items in this cluster are:
# 830:['makai_kingdom', 'chronicles', 'sacred', 'tome']
# ----------------------------------
#
# Originals as noise, names:
# ['james', 'bond', '007', 'nightfire']
# Would be reclassified into: 91
# With accuracy: 0.010381284603331792
# Items in this cluster are:
# 91:['james_bond', 'everything_nothing']
# 91:['james_bond', 'everything_nothing']
# 91:['james_bond', 'everything_nothing']
# 91:['james_bond', 'everything_nothing']
# 91:['james_bond', 'everything_nothing', 'promo']
# 91:['james_bond', 'everything_nothing']
# ----------------------------------
#
# Originals as noise, names:
# ['trivial', 'pursuit']
# ['trivial', 'pursuit']
# Would be reclassified into: 1231
# With accuracy: 0.0014223935159845675
# Items in this cluster are:
# 1231:['trivial_pursuit', 'haluatko', 'miljonääriksi']
# ----------------------------------
#
# Originals as noise, names:
# ['makai', 'kingdom']
# ['makai', 'kingdom']
# Would be reclassified into: 830
# With accuracy: 0.0013723989956249034
# Items in this cluster are:
# 830:['makai_kingdom', 'chronicles', 'sacred', 'tome']
# ----------------------------------
#
# Originals as noise, names:
# ['commandos', '2']
# Would be reclassified into: 451
# With accuracy: 0.010274227837339299
# Items in this cluster are:
# 451:['commandos_2', 'men_courage']
# 451:['commandos_2', 'men_courage']
# 451:['commandos_2', 'men_courage', 'ps_ii']
# 451:['commandos_2', 'men_courage']
# ----------------------------------
#
# Originals as noise, names:
# ['battle', 'bacific']
# Would be reclassified into: 1202
# With accuracy: 0.0014096984216404912
# Items in this cluster are:
# 1202:['battle', 'engine', 'aquila']
# ----------------------------------
#
# Originals as noise, names:
# ['wild', 'arms', '3', 'pal']
# Would be reclassified into: 717
# With accuracy: 0.003871036111397532
# Items in this cluster are:
# 717:['wild_arms', '3']
# 717:['wild_arms', '3']
# ----------------------------------
#
# Originals as noise, names:
# ['go', 'go', 'golf']
# ['grazy', 'golf']
# ['leaderboard', 'golf']
# Would be reclassified into: 1544
# With accuracy: 0.001430140927054757
# Items in this cluster are:
# 1544:['mr', 'golf']
# ----------------------------------
#
# Originals as noise, names:
# ['barbie', 'island', 'princessps2']
# Would be reclassified into: 1569
# With accuracy: 0.0014457920835415636
# Items in this cluster are:
# 1569:['barbie_island', 'princess']
# ----------------------------------
#
# Originals as noise, names:
# ['pinball']
# ['powershot', 'pinball']
# Would be reclassified into: 589
# With accuracy: 0.007179912597707362
# Items in this cluster are:
# 589:['play_it', 'pinball']
# 589:['play_it', 'pinball']
# 589:['play_it', 'pinball']
# ----------------------------------
#
# Originals as noise, names:
# ['gift']
# Would be reclassified into: 24
# With accuracy: 0.001704808294593314
# Items in this cluster are:
# 24:['ford_racing', '3']
# 24:['speed_machines', '3']
# 24:['rainbow_six', '3']
# 24:['gift', '3', 'harvinainen']
# 24:['call_duty', '3']
# 24:['toy_story', '3']
# 24:['toy_story', '3']
# 24:['toy_story', '3']
# 24:['toy_story', '3']
# 24:['toy_story', '3']
# 24:['toy_story', '3']
# ----------------------------------
#
# Originals as noise, names:
# ['fighting', 'fury']
# ['fighting', 'angelsps2']
# Would be reclassified into: 1551
# With accuracy: 0.0014180187668310004
# Items in this cluster are:
# 1551:['pride', 'fighting', 'championships']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'gun', 'pal']
# Would be reclassified into: 1581
# With accuracy: 0.0014461330921436625
# Items in this cluster are:
# 1581:['gun_pal', 'sinetöity']
# ----------------------------------
#
# Originals as noise, names:
# ['unlimited', 'saga']
# Would be reclassified into: 750
# With accuracy: 0.001371186703069472
# Items in this cluster are:
# 750:['king_fighters', 'collection', 'orochi', 'saga']
# ----------------------------------
#
# Originals as noise, names:
# ['espn', 'nba', 'basketball']
# Would be reclassified into: 586
# With accuracy: 0.0067113926603021064
# Items in this cluster are:
# 586:['espn_nba', '2k5']
# 586:['espn_nba', '2k5', 'huippu']
# 586:['espn_nba', '2k5']
# ----------------------------------
#
# Originals as noise, names:
# ['oni']
# ['oni']
# Would be reclassified into: 1042
# With accuracy: 0.001298471946383192
# Items in this cluster are:
# 1042:['oni', 'dark', 'future', 'uncertain', 'past']
# ----------------------------------
#
# Originals as noise, names:
# ['midnight', 'club', 'street', 'racing']
# Would be reclassified into: 147
# With accuracy: 0.005080005410163618
# Items in this cluster are:
# 147:['midnight_club', '3_dub', 'edition_remix']
# 147:['midnight_club', '3_dub', 'edition_remix']
# 147:['midnight_club', '3_dub', 'edition_remix']
# 147:['midnight_club', '3_dub', 'edition_remix']
# 147:['midnight_club', '3_dub', 'edition_remix']
# 147:['midnight_club', '3_dub', 'edition_remix']
# ----------------------------------
#
# Originals as noise, names:
# ['call', 'duty', 'trilogy', 'boxi']
# Would be reclassified into: 150
# With accuracy: 0.01579100872693494
# Items in this cluster are:
# 150:['call_duty', 'finest_hour']
# 150:['call_duty', 'finest_hour']
# 150:['call_duty', 'finest_hour']
# 150:['call_duty', 'finest_hour']
# 150:['ps_2', 'call_duty', 'finest_hour', 'pal']
# 150:['call_duty', 'finest_hour']
# 150:['call_duty', 'finest_hour', 'playstation_2', 'ntsc']
# 150:['call_duty', 'finest_hour']
# ----------------------------------
#
# Originals as noise, names:
# ['little', 'britain', 'video', 'game']
# Would be reclassified into: 1117
# With accuracy: 0.0014223935159845675
# Items in this cluster are:
# 1117:['pikku', 'britannia', 'little_britain', 'video_game']
# ----------------------------------
#
# Originals as noise, names:
# ['persona', '3', 'fes']
# Would be reclassified into: 1208
# With accuracy: 0.0014217243715860357
# Items in this cluster are:
# 1208:['shin_megami', 'tensei', 'persona_3', 'pal']
# ----------------------------------
#
# Originals as noise, names:
# ['metropolismania', 'ps', 'ii']
# ['ps', '2', 'pes', 'management', 'pal']
# ['vegas', 'casino']
# Would be reclassified into: 5
# With accuracy: 0.0016554050045650569
# Items in this cluster are:
# 5:['soulcalibur', '2']
# 5:['pes', '2']
# 5:['warriors_orochi', '2']
# 5:['castle_shikigami', '2']
# 5:['time_crisis', '2']
# 5:['vegas_casino', '2']
# 5:['ice_age', '2']
# 5:['midnight_club', '2']
# 5:['metropolismania', '2']
# 5:['warriors_orochi', '2']
# ----------------------------------
#
# Originals as noise, names:
# ['formula', 'one', '2005']
# Would be reclassified into: 622
# With accuracy: 0.009095595142888331
# Items in this cluster are:
# 622:['formula_one', '2003', '12129']
# 622:['formula_one', '2003']
# 622:['formula_one', '2003', '424']
# 622:['formula_one', '2003']
# ----------------------------------
#
# Originals as noise, names:
# ['dragon', 'rage']
# Would be reclassified into: 829
# With accuracy: 0.007208078162782172
# Items in this cluster are:
# 829:['simpsons_road', 'rage']
# 829:['simpsons_road', 'rage']
# 829:['simpsons_road', 'rage']
# ----------------------------------
#
# Originals as noise, names:
# ['hitman', '–', 'contracts']
# Would be reclassified into: 626
# With accuracy: 0.0012985329513421557
# Items in this cluster are:
# 626:['hitman', 'blood', 'money', 'steel', 'book']
# ----------------------------------
#
# Originals as noise, names:
# ['tourist', 'trophy']
# Would be reclassified into: 744
# With accuracy: 0.0013727710097110764
# Items in this cluster are:
# 744:['tourist_trophy', 'real', 'riding', 'simulator', 'playstation_2']
# ----------------------------------
#
# Originals as noise, names:
# ['evil', 'dead', 'playstation', 'pelit']
# Would be reclassified into: 382
# With accuracy: 0.010243157258052726
# Items in this cluster are:
# 382:['evil_dead', 'fistful_boomstick']
# 382:['evil_dead', 'fistful_boomstick']
# 382:['evil_dead', 'fistful_boomstick']
# 382:['evil_dead', 'fistful_boomstick']
# ----------------------------------
#
# Originals as noise, names:
# ['breath', 'fire', 'dragon', 'quarter', 'pal']
# Would be reclassified into: 800
# With accuracy: 0.00349726704218078
# Items in this cluster are:
# 800:['breath_fire', 'v', 'dragon_quarter', 'japani']
# ----------------------------------
#
# Originals as noise, names:
# ['pelejä', '6kpl']
# Would be reclassified into: 1526
# With accuracy: 0.0014464653786233532
# Items in this cluster are:
# 1526:['fifa', 'pelejä_6kpl']
# ----------------------------------
#
# Originals as noise, names:
# ['xtreme', 'cheats']
# Would be reclassified into: 828
# With accuracy: 0.003383365952228431
# Items in this cluster are:
# 828:['skateboard_madness', 'xtreme', 'editionps2']
# 828:['skateboard_madness', 'xtreme', 'edition']
# ----------------------------------
#
# Originals as noise, names:
# ['tony', 'hawk´s', 'project', '8']
# Would be reclassified into: 1560
# With accuracy: 0.001446489739376345
# Items in this cluster are:
# 1560:['tony_hawk´s', 'proving_ground']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'karaoke', 'stage', 'pal']
# Would be reclassified into: 1557
# With accuracy: 0.0014123548562460773
# Items in this cluster are:
# 1557:['karaoke_stage', '2']
# ----------------------------------
#
# Originals as noise, names:
# ['drakan']
# Would be reclassified into: 1170
# With accuracy: 0.0014223935159845675
# Items in this cluster are:
# 1170:['drakan', 'ancients', 'gates']
# ----------------------------------
#
# Originals as noise, names:
# ['off', 'road']
# ['off', 'road']
# Would be reclassified into: 1052
# With accuracy: 0.0014464756356557871
# Items in this cluster are:
# 1052:['ford', 'off_road']
# ----------------------------------
#
# Originals as noise, names:
# ['pelit', '6', 'kpl']
# Would be reclassified into: 1345
# With accuracy: 0.001421599286186655
# Items in this cluster are:
# 1345:['pelejä', '10€', 'kpl']
# ----------------------------------
#
# Originals as noise, names:
# ['formula', 'challenge']
# ['lotus', 'challenge']
# Would be reclassified into: 210
# With accuracy: 0.013063679798990396
# Items in this cluster are:
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['grand_prix', 'challenge']
# 210:['ps_2', 'grand_prix', 'challenge', 'b_pal']
# ----------------------------------
#
# Originals as noise, names:
# ['ps', '2', 'pelit', 'x', '8']
# Would be reclassified into: 160
# With accuracy: 0.016883796027494107
# Items in this cluster are:
# 160:['final_fantasy', 'x']
# 160:['final_fantasy', 'x']
# 160:['final_fantasy', 'x']
# 160:['final_fantasy', 'x']
# 160:['final_fantasy', 'x']
# 160:['final_fantasy', 'x', 'dvd']
# 160:['ps_2', 'final_fantasy', 'x', 'b_pal']
# 160:['final_fantasy', 'x']
# ----------------------------------
#
# Originals as noise, names:
# ['knockout', 'kings', '2002']
# ['cricket', '2002']
# ['madden', 'nfl', '2002']
# Would be reclassified into: 495
# With accuracy: 0.005986874183200796
# Items in this cluster are:
# 495:['is_football', '2002', 'platinum']
# 495:['is_football', '2002']
# 495:['is_football', '2002']
# ----------------------------------
#
# Originals as noise, names:
# ['nba', '08']
# ['ps', '2', 'nba', 'live', '2005', 'b', 'pal']
# Would be reclassified into: 394
# With accuracy: 0.011711278962504927
# Items in this cluster are:
# 394:['nba_live', '08']
# 394:['nba_live', '08']
# 394:['nba_live', '08']
# 394:['nba_live', '08']
# 394:['nba_live', '08']

# %%
# Change the label numbers of properly predicted classes

for i,row in enumerate(goodPreds):
    #print(y_hc[noises.at[row[0],'index1']])
    y_hc[noises.at[row[0],'index1']]=row[1]
    #print(y_hc[noises.at[row[0],'index1']])
    #print("----------------------------")
# Out:
# 62
# 406
# ----------------------------
# 62
# 1451
# ----------------------------
# 62
# 1404
# ----------------------------
# 62
# 263
# ----------------------------
# 62
# 1601
# ----------------------------
# 62
# 456
# ----------------------------
# 62
# 1559
# ----------------------------
# 62
# 154
# ----------------------------
# 62
# 244
# ----------------------------
# 62
# 1036
# ----------------------------
# 62
# 524
# ----------------------------
# 62
# 1333
# ----------------------------
# 62
# 617
# ----------------------------
# 62
# 1059
# ----------------------------
# 62
# 331
# ----------------------------
# 62
# 1217
# ----------------------------
# 62
# 331
# ----------------------------
# 62
# 402
# ----------------------------
# 62
# 663
# ----------------------------
# 62
# 421
# ----------------------------
# 62
# 245
# ----------------------------
# 62
# 1059
# ----------------------------
# 62
# 1129
# ----------------------------
# 62
# 148
# ----------------------------
# 62
# 67
# ----------------------------
# 62
# 798
# ----------------------------
# 62
# 1225
# ----------------------------
# 62
# 280
# ----------------------------
# 62
# 1470
# ----------------------------
# 62
# 245
# ----------------------------
# 62
# 500
# ----------------------------
# 62
# 582
# ----------------------------
# 62
# 930
# ----------------------------
# 62
# 495
# ----------------------------
# 62
# 703
# ----------------------------
# 62
# 1104
# ----------------------------
# 62
# 394
# ----------------------------
# 62
# 939
# ----------------------------
# 62
# 1280
# ----------------------------
# 62
# 1314
# ----------------------------
# 62
# 727
# ----------------------------
# 62
# 236
# ----------------------------
# 62
# 1314
# ----------------------------
# 62
# 395
# ----------------------------
# 62
# 766
# ----------------------------
# 62
# 1011
# ----------------------------
# 62
# 1508
# ----------------------------
# 62
# 940
# ----------------------------
# 62
# 806
# ----------------------------
# 62
# 324
# ----------------------------
# 62
# 952
# ----------------------------
# 62
# 1586
# ----------------------------
# 62
# 300
# ----------------------------
# 62
# 84
# ----------------------------
# 62
# 1191
# ----------------------------
# 62
# 975
# ----------------------------
# 62
# 210
# ----------------------------
# 62
# 154
# ----------------------------
# 62
# 1262
# ----------------------------
# 62
# 406
# ----------------------------
# 62
# 318
# ----------------------------
# 62
# 159
# ----------------------------
# 62
# 795
# ----------------------------
# 62
# 300
# ----------------------------
# 62
# 573
# ----------------------------
# 62
# 1423
# ----------------------------
# 62
# 48
# ----------------------------
# 62
# 990
# ----------------------------
# 62
# 1067
# ----------------------------
# 62
# 599
# ----------------------------
# 62
# 351
# ----------------------------
# 62
# 95
# ----------------------------
# 62
# 587
# ----------------------------
# 62
# 1631
# ----------------------------
# 62
# 851
# ----------------------------
# 62
# 1551
# ----------------------------
# 62
# 406
# ----------------------------
# 62
# 490
# ----------------------------
# 62
# 113
# ----------------------------
# 62
# 1195
# ----------------------------
# 62
# 518
# ----------------------------
# 62
# 5
# ----------------------------
# 62
# 406
# ----------------------------
# 62
# 781
# ----------------------------
# 62
# 749
# ----------------------------
# 62
# 679
# ----------------------------
# 62
# 163
# ----------------------------
# 62
# 516
# ----------------------------
# 62
# 1544
# ----------------------------
# 62
# 754
# ----------------------------
# 62
# 1231
# ----------------------------
# 62
# 587
# ----------------------------
# 62
# 1304
# ----------------------------
# 62
# 945
# ----------------------------
# 62
# 128
# ----------------------------
# 62
# 1561
# ----------------------------
# 62
# 148
# ----------------------------
# 62
# 1106
# ----------------------------
# 62
# 516
# ----------------------------
# 62
# 406
# ----------------------------
# 62
# 5
# ----------------------------
# 62
# 389
# ----------------------------
# 62
# 226
# ----------------------------
# 62
# 1544
# ----------------------------
# 62
# 762
# ----------------------------
# 62
# 95
# ----------------------------
# 62
# 1210
# ----------------------------
# 62
# 495
# ----------------------------
# 62
# 1042
# ----------------------------
# 62
# 75
# ----------------------------
# 62
# 1519
# ----------------------------
# 62
# 1052
# ----------------------------
# 62
# 85
# ----------------------------
# 62
# 918
# ----------------------------
# 62
# 1106
# ----------------------------
# 62
# 723
# ----------------------------
# 62
# 894
# ----------------------------
# 62
# 1341
# ----------------------------
# 62
# 662
# ----------------------------
# 62
# 230
# ----------------------------
# 62
# 1236
# ----------------------------
# 62
# 1149
# ----------------------------
# 62
# 589
# ----------------------------
# 62
# 830
# ----------------------------
# 62
# 91
# ----------------------------
# 62
# 1231
# ----------------------------
# 62
# 830
# ----------------------------
# 62
# 451
# ----------------------------
# 62
# 1202
# ----------------------------
# 62
# 717
# ----------------------------
# 62
# 1544
# ----------------------------
# 62
# 1569
# ----------------------------
# 62
# 589
# ----------------------------
# 62
# 24
# ----------------------------
# 62
# 1551
# ----------------------------
# 62
# 1581
# ----------------------------
# 62
# 750
# ----------------------------
# 62
# 586
# ----------------------------
# 62
# 1042
# ----------------------------
# 62
# 147
# ----------------------------
# 62
# 150
# ----------------------------
# 62
# 1117
# ----------------------------
# 62
# 1208
# ----------------------------
# 62
# 5
# ----------------------------
# 62
# 622
# ----------------------------
# 62
# 829
# ----------------------------
# 62
# 626
# ----------------------------
# 62
# 744
# ----------------------------
# 62
# 382
# ----------------------------
# 62
# 800
# ----------------------------
# 62
# 1526
# ----------------------------
# 62
# 828
# ----------------------------
# 62
# 1560
# ----------------------------
# 62
# 1557
# ----------------------------
# 62
# 1170
# ----------------------------
# 62
# 1052
# ----------------------------
# 62
# 1345
# ----------------------------
# 62
# 210
# ----------------------------
# 62
# 160
# ----------------------------
# 62
# 495
# ----------------------------
# 62
# 394
# ----------------------------

# %%
# Drop the rows from noises that have already been reclassified

for i,row in enumerate(goodPreds):
    noises=noises.drop(i)

# %%
# Relabel rest of noise items with their new label+amount of previous clusters

for index, row in noises.iterrows():
    y_hc[row['index1']]=y_hc2[index]+n_clusters

# %%
# See if the reclassification worked

fixedTest = 1559
for row in y_hc:
    if row == fixedTest:
        print(row)
# Out:
# 1559
# 1559

# %%
# Insert the new labels into the dataframe

dropdf1['label']=y_hc
sentences.loc[y_hc==fixedTest]
# Out:
#                          title  \
# 343   [zapper, playstation, 2]
# 2243             [zapper, 415]
#
#                                                   links  currentPrice  \
# 343   {'self': 'https://api.huuto.net/1.1/items/5225...          20.0
# 2243  {'self': 'https://api.huuto.net/1.1/items/5254...           5.0
#
#                       bigrams
# 343   [zapper, playstation_2]
# 2243            [zapper, 415]

# %%
# See how many clusters we have now

dropdf1['label'].nunique()
# Out:
# 1816

# %%
# Make df where cluster data is stored
# Columns: Cluster_id, average, median, item links, cluster name, (cluster bigrams)
clusterdf = pd.DataFrame(columns={'cTitle','iTitleList','cNum','mean','median','links','itemCount','priceList'})

for index, sentence in sentences.iterrows():
    cTitle = []
    cTitleList = []
    cNum = index
    mean = None
    median = None
    links= []
    itemCount = 0
    iTitleList = []
    
    priceList = []
    
    for jndex, jentence in sentences.iterrows():
        if(y_hc[jndex]==index):             
            #print(str(y_hc[jndex])+ ":" + str(jentence))
            
            # Add all cluster item titles to iTitleList
            iTitleList.append(jentence['title'])
            
            # Add title to iTitleList
            links.append(jentence['links'].get('alternative'))
            
            #Add one to itemCount
            itemCount += 1
            
            # Add price to priceList
            priceList.append(jentence['currentPrice'])
            
            
    # Calculate title for cluster (cTitle)
    for row in iTitleList:
        for word in row:
            if word not in cTitle:
                cTitle.append(word)
    
    priceList = np.array(priceList)
    # Calculate mean
    mean = np.mean(priceList)
    
    # Calculate median
    median = np.median(priceList)
    
    clusterdf = clusterdf.append({'cTitle':cTitle,'iTitleList': iTitleList,'cNum':cNum,
                                  'mean':mean,'median':median,'links':links,
                                  'itemCount':itemCoungt,'priceList':priceList}, ignore_index=True)
    if index > n_clusters:
        break

# %%
check = 495
#clusterdf[:check]
print(clusterdf['cTitle'][check])
print(clusterdf['links'][check])
clusterdf.loc[check]
# Out:
# ['is', 'football', '2002', 'platinum', 'knockout', 'kings']
# ['https://www.huuto.net/kohteet/this-is-football-2002-platinum-ps2--40/521058892', 'https://www.huuto.net/kohteet/knockout-kings-2002-ps2/524753663', 'https://www.huuto.net/kohteet/this-is-football-2002-ps2/526313211', 'https://www.huuto.net/kohteet/this-is-football-2002-ps2/526153006']
# mean                                                     2.4375
# iTitleList    [[is, football, 2002, platinum], [knockout, ki...
# priceList                                 [2.95, 3.0, 2.0, 1.8]
# cNum                                                        495
# median                                                    2.475
# links         [https://www.huuto.net/kohteet/this-is-footbal...
# itemCount                                                     4
# cTitle          [is, football, 2002, platinum, knockout, kings]
# Name: 495, dtype: object

# %%
clusterdf = clusterdf[:n_clusters]

# %%
clusterdf.to_csv("huutoClusters21_10.csv",index=False)

# %%
# Make search logic
